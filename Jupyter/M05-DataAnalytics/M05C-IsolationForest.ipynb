# %% [markdown]
#     ![Cloud-First](../image/CloudFirst.png)
#
#     # SIT742: Modern Data Science
#     **(Module 05: Data Analytics)**
#
#     **Session 5C: Isolation Forest Anomaly Detection**
#
#     ---
#
#     - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
#     - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
#     - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
#     - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
#     - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
#     Prepared by the SIT742 Teaching Team.
#
#     Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
#     ---
#
#     <div align="center">
#
#     <table>
#     <thead>
#     <tr>
#     <th><strong>Item</strong></th>
#     <th><strong>Description</strong></th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#     <td align="left">Module context</td>
#     <td>This notebook is one component of the practical and self-learning materials for Module 05.</td>
#     </tr>
#     <tr>
#     <td align="left">Estimated duration</td>
#     <td>Approximately 48 minutes, based on 240 minutes of M05 practical/self-learning work divided across five M05 notebooks.</td>
#     </tr>
#     <tr>
#     <td align="left">Main packages</td>
#     <td><code>pandas</code>, <code>numpy</code>, <code>matplotlib</code>, <code>seaborn</code>, and <code>scikit-learn</code>.</td>
#     </tr>
#     <tr>
#     <td align="left">Data files</td>
#     <td><code>Australia_HK.csv</code> from the public <code>Jupyter/data/</code> folder.</td>
#     </tr>
#     <tr>
#     <td align="left">Related assessment</td>
#     <td>General practical skill development; not directly assessed.</td>
#     </tr>
#     </tbody>
#     </table>
#
#     </div>
#
#     ---
#
#     **Table of Contents**
#
#     - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Data Files](#2-setup-and-data-files)
# - [3. Anomaly Detection Concepts](#3-anomaly-detection-concepts)
# - [4. Data Preparation and Scaling](#4-data-preparation-and-scaling)
# - [5. Exploratory Plots](#5-exploratory-plots)
# - [6. Isolation Forest](#6-isolation-forest)
# - [7. Multi-Feature Anomaly Scores](#7-multi-feature-anomaly-scores)
# - [8. Student Tasks](#8-student-tasks)
# - [9. Checks and Reflection](#9-checks-and-reflection)
# - [10. Reflection and References](#10-reflection-and-references)
#
#     ---

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# Anomaly detection looks for observations that are unusual relative to the rest of the data. In this practical you will use a public Hong Kong arrivals and search-interest dataset, scale selected numeric features, inspect exploratory plots, and fit an unsupervised Isolation Forest model.
#
# By the end of this practical, you should be able to:
#
# 1. load and inspect a public multivariate time-indexed dataset;
# 2. scale numeric variables before comparing them visually;
# 3. use violin and box plots to inspect potential outliers;
# 4. fit an Isolation Forest model to one variable;
# 5. compare anomaly scores across multiple numeric features.

# %% [markdown]
# <a id="2-setup-and-data-files"></a>
#
# ### 2. Setup and Data Files
#
# This notebook uses `Australia_HK.csv`, a public SIT742 copy of the Hong Kong arrivals and search-interest dataset used in this activity. Use online mode unless you are running from a cloned local SIT742 repository.

# %%
from pathlib import Path
from urllib.request import urlretrieve
import importlib.util
import subprocess
import sys
import tempfile
import warnings

PUBLIC_DATA_BASE_URL = "https://raw.githubusercontent.com/tulip-lab/sit742/develop/Jupyter/data"
EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a cloned SIT742 repository.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"


def ensure_packages_available(package_map):
    missing = [pip_name for import_name, pip_name in package_map.items() if importlib.util.find_spec(import_name) is None]
    if not missing:
        return
    if INSTALL_MISSING_PACKAGES:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *missing])
        return
    raise ModuleNotFoundError(
        "Missing required packages: "
        + ", ".join(missing)
        + ". Install them in the active environment, or set EXECUTION_MODE = 'online' to install them in an online notebook runtime."
    )


def download_public_data(required_files, prefix):
    data_dir = Path(tempfile.mkdtemp(prefix=prefix))
    downloaded_paths = {}
    for filename in required_files:
        url = f"{PUBLIC_DATA_BASE_URL}/{filename}"
        local_file = data_dir / filename
        urlretrieve(url, local_file)
        downloaded_paths[filename] = local_file
    return data_dir, downloaded_paths


def find_local_data_dir(required_files):
    cwd = Path.cwd().resolve()
    candidates = []
    for base in [cwd, *cwd.parents]:
        candidates.extend([base / "Jupyter" / "data", base / "data"])
    for candidate in candidates:
        if all((candidate / filename).exists() for filename in required_files):
            return candidate, {filename: candidate / filename for filename in required_files}
    checked = "\n".join(str(candidate) for candidate in candidates)
    raise FileNotFoundError(
        "Could not find the public SIT742 data files locally. "
        "Set EXECUTION_MODE = 'online' or run this notebook from a cloned SIT742 repository.\n"
        f"Checked:\n{checked}"
    )


def resolve_data_files(required_files, prefix):
    if EXECUTION_MODE == "online":
        return download_public_data(required_files, prefix)
    if EXECUTION_MODE == "local":
        return find_local_data_dir(required_files)
    raise ValueError("EXECUTION_MODE must be either 'online' or 'local'.")

ensure_packages_available({
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "seaborn": "seaborn",
    "sklearn": "scikit-learn",
})

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.ensemble import IsolationForest

warnings.filterwarnings("ignore")

required_files = ["Australia_HK.csv"]
DATA_DIR, data_files = resolve_data_files(required_files, "sit742_m05c_data_")
DataSet = data_files["Australia_HK.csv"]

df = pd.read_csv(DataSet)
df["date"] = pd.to_datetime(df["date"], format="%Y-%m")

print("Execution mode:", EXECUTION_MODE)
print("Data folder:", DATA_DIR)
print("Data shape:", df.shape)
df.head(10)

# %% [markdown]
# <a id="3-anomaly-detection-concepts"></a>
#
# ### 3. Anomaly Detection Concepts
#
# An anomaly is an observation that differs strongly from the usual pattern. An anomaly is not automatically an error; it may be a genuine event, a data-quality issue, or a sign that the modelling assumptions are incomplete.
#
# Isolation Forest is an unsupervised method. It builds many random trees and identifies observations that are easier to isolate. Points that need shorter random paths to be separated are treated as more unusual.

# %% [markdown]
# <a id="4-data-preparation-and-scaling"></a>
#
# ### 4. Data Preparation and Scaling
#
# This practical compares `arrival`, `Hong kong`, and `Hong kong dollar`. These variables are on different scales, so min-max scaling makes the exploratory plots easier to compare.

# %%
selected_features = ["arrival", "Hong kong", "Hong kong dollar"]
df_model = df[["date", *selected_features]].copy()

min_max_scaler = preprocessing.MinMaxScaler()
df_normal = df.copy()
df_normal[selected_features] = min_max_scaler.fit_transform(df_model[selected_features])

df_model.describe()

# %%
df_normal[["date", *selected_features]].head()

# %% [markdown]
# <a id="5-exploratory-plots"></a>
#
# ### 5. Exploratory Plots
#
# Violin and box plots provide quick visual checks for distribution shape, spread, and unusually high or low values.

# %%
df_eda = df_normal.melt(
    id_vars="date",
    value_vars=selected_features,
    var_name="category",
    value_name="value",
)

fig, ax = plt.subplots(figsize=(10, 5))
sns.violinplot(x="category", y="value", data=df_eda, ax=ax)
ax.set_title("Scaled feature distributions")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.boxplot(x="category", y="value", data=df_eda, ax=ax)
ax.set_title("Scaled feature outlier inspection")
plt.show()

# %% [markdown]
# <a id="6-isolation-forest"></a>
#
# ### 6. Isolation Forest
#
# The first model focuses on the `arrival` variable. Set a `random_state` so the example is reproducible.

# %%
rng = np.random.RandomState(0)
arrival_model = IsolationForest(max_samples=min(100, len(df_model)), random_state=rng, contamination="auto")
arrival_model.fit(df_model[["arrival"]])

score_df = df_model[["date", "arrival"]].copy()
score_df["anomaly_score"] = arrival_model.decision_function(df_model[["arrival"]])
score_df["anomaly"] = arrival_model.predict(df_model[["arrival"]])
anomalies = score_df.loc[score_df["anomaly"] == -1]

print("Number of arrival anomalies:", len(anomalies))
anomalies.head()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(score_df["date"], score_df["arrival"], label="Arrival")
ax.scatter(anomalies["date"], anomalies["arrival"], color="red", label="Detected anomaly", zorder=5)
ax.set_title("Isolation Forest anomalies in arrivals")
ax.set_xlabel("Date")
ax.set_ylabel("Arrivals")
ax.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="7-multi-feature-anomaly-scores"></a>
#
# ### 7. Multi-Feature Anomaly Scores
#
# The next step explores anomaly scores for multiple numeric columns and summarises the anomaly count for each numeric feature.

# %%
numeric_columns = [column for column in df.select_dtypes(include=[np.number]).columns if column != "date"]
feature_scores = []

for column in numeric_columns:
    model = IsolationForest(max_samples=min(100, len(df)), random_state=0, contamination="auto")
    values = df[[column]].fillna(df[[column]].median(numeric_only=True))
    predictions = model.fit_predict(values)
    feature_scores.append({
        "feature": column,
        "anomaly_count": int((predictions == -1).sum()),
        "anomaly_rate": float((predictions == -1).mean()),
    })

feature_score_df = pd.DataFrame(feature_scores).sort_values(
    ["anomaly_count", "feature"], ascending=[False, True]
)
feature_score_df.head(10)

# %% [markdown]
# <a id="8-student-tasks"></a>
#
# ### 8. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Fit Isolation Forest to `Hong kong` instead of `arrival`.</td>
# <td>Different features can reveal different unusual months.</td>
# <td>A table of detected anomalies and one comparison sentence.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Change the `contamination` value to a small fixed value such as `0.05`.</td>
# <td>The assumed anomaly rate affects the number of flagged points.</td>
# <td>An anomaly count before and after the change.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Select three search-interest columns and compare their anomaly rates.</td>
# <td>Feature choice changes the practical meaning of an anomaly.</td>
# <td>A compact table and interpretation.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %%
# Student workspace
# feature_name = "Hong kong"
# model = IsolationForest(max_samples=min(100, len(df)), random_state=0, contamination=0.05)
# ...

# %% [markdown]
# <a id="9-checks-and-reflection"></a>
#
# ### 9. Checks and Reflection

# %%
assert df.shape[0] == 84
assert set(selected_features).issubset(df.columns)
assert set(score_df["anomaly"].unique()).issubset({-1, 1})
assert not feature_score_df.empty

print("Checks passed.")
print("Rows:", df.shape[0])
print("Numeric features scored:", len(feature_score_df))

# %% [markdown]
# <a id="10-reflection-and-references"></a>
#
# ### 10. Reflection and References
#
# Reflection questions:
#
# 1. Which detected arrival anomaly looks most plausible as a real event, and why?
# 2. How does scaling affect visual comparison across variables?
# 3. Why should anomaly detection be followed by contextual investigation?
#
# Further reading:
#
# - [scikit-learn IsolationForest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html)
# - [scikit-learn outlier detection overview](https://scikit-learn.org/stable/modules/outlier_detection.html)
# - [pandas reshaping with melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html)
#
# Dataset note: `Australia_HK.csv` is provided through the public SIT742 repository for teaching use.
