# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 05: Data Analytics)**
#
# **Session 5F: Advanced Time Series Forecasting**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for Module 05.</td>
# </tr>
# <tr>
# <td align="left">Estimated duration</td>
# <td>Approximately 48 minutes, based on 240 minutes of M05 practical/self-learning work divided across five M05 notebooks.</td>
# </tr>
# <tr>
# <td align="left">Main packages</td>
# <td><code>pandas</code>, <code>numpy</code>, <code>matplotlib</code>, <code>scikit-learn</code>, <code>yfinance</code>, and <code>torch</code>.</td>
# </tr>
# <tr>
# <td align="left">Data files</td>
# <td>No local data file is required. The notebook uses live <code>yfinance</code> market data when available and creates a reproducible synthetic OHLC dataset as an online fallback.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ### Table of Contents
#
# 1. [Overview and Learning Goals](#1-overview-and-learning-goals)
# 2. [Setup and Data Source](#2-setup-and-data-source)
# 3. [Forecasting and Attention Concepts](#3-forecasting-and-attention-concepts)
# 4. [Market Data Preparation](#4-market-data-preparation)
# 5. [LSTM-Attention Dataset](#5-lstm-attention-dataset)
# 6. [Model Training and Prediction](#6-model-training-and-prediction)
# 7. [Attention Score Exploration](#7-attention-score-exploration)
# 8. [Student Tasks](#8-student-tasks)
# 9. [Checks and Reflection](#9-checks-and-reflection)
# 10. [Reflection and References](#10-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# Advanced time-series forecasting extends the basic forecasting workflow by using a sequence model that can learn from a window of recent observations. In this practical you will prepare market-style time-series data, train a compact LSTM model, add a temporal attention layer, and inspect the attention weights as one form of model diagnostic.
#
# By the end of this practical, you should be able to:
#
# 1. load live or fallback OHLC time-series data in an online notebook environment;
# 2. scale multivariate time-series features for neural-network training;
# 3. build chronological lookback windows for next-day forecasting;
# 4. train a compact PyTorch LSTM with a temporal attention layer;
# 5. compare model predictions with a simple baseline;
# 6. interpret attention scores cautiously as model diagnostics rather than as proof of causality.

# %% [markdown]
# <a id="2-setup-and-data-source"></a>
#
# ### 2. Setup and Data Source
#
# This notebook is designed for Google Colab and other online notebook environments. It uses live `yfinance` data for Apple Inc. (`AAPL`) when the service is reachable. Live market data can change or become temporarily unavailable, so the notebook also includes a reproducible synthetic OHLC fallback dataset.
#
# #### Option A: Google Colab / online execution
#
# Keep `EXECUTION_MODE = "online"` and `DATA_SOURCE_MODE = "auto"`. The setup cell installs lightweight missing packages where possible and uses the synthetic fallback if the live data request fails.
#
# #### Option B: Local execution
#
# Use this option only when your local Python environment already has the required packages installed. Change `EXECUTION_MODE` to `"local"` if you do not want the notebook to install missing packages. PyTorch installation is platform-specific, so install it from the official PyTorch instructions before running locally.

# %%
from pathlib import Path
import importlib.util
import subprocess
import sys
import warnings

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" only for a prepared local environment.
DATA_SOURCE_MODE = "auto"  # Use "auto", "live", or "synthetic".
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"

TICKER = "AAPL"
START_DATE = "2020-01-01"
END_DATE = "2023-01-01"
LOOKBACK_DAYS = 20
TRAIN_FRACTION = 0.8
EPOCHS = 20
HIDDEN_DIM = 32
LEARNING_RATE = 0.01
RANDOM_SEED = 42


def ensure_packages_available(package_map):
    missing = [pip_name for import_name, pip_name in package_map.items() if importlib.util.find_spec(import_name) is None]
    if not missing:
        return
    if INSTALL_MISSING_PACKAGES:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *missing])
        return
    raise ModuleNotFoundError(
        "Missing required packages: "
        + ", ".join(missing)
        + ". Install them in the active environment, or set EXECUTION_MODE = 'online' in an online notebook runtime."
    )


ensure_packages_available(
    {
        "numpy": "numpy",
        "pandas": "pandas",
        "matplotlib": "matplotlib",
        "sklearn": "scikit-learn",
        "yfinance": "yfinance",
    }
)

if importlib.util.find_spec("torch") is None:
    raise ModuleNotFoundError(
        "PyTorch is required for the LSTM section. Google Colab usually includes it. "
        "For local execution, install PyTorch for your platform from https://pytorch.org/get-started/locally/."
    )

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
import yfinance as yf

np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(RANDOM_SEED)

warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# <a id="3-forecasting-and-attention-concepts"></a>
#
# ### 3. Forecasting and Attention Concepts
#
# This practical forecasts the next available daily `Low` value from a recent window of `Open`, `High`, and `Low` values.
#
# Important modelling choices:
#
# - **Chronological split**: the training observations come before the testing observations, which avoids using future records to train a time-series model.
# - **Lookback window**: each input sequence contains the previous `LOOKBACK_DAYS` rows.
# - **Scaling**: neural networks train more reliably when numeric inputs are on comparable scales.
# - **Baseline comparison**: the previous day's `Low` value is a simple benchmark. A complex model should be judged against simple alternatives.
# - **Temporal attention**: the attention layer creates weights over the lookback days. These weights can help inspect what the model used, but they are not causal explanations.

# %% [markdown]
# <a id="4-market-data-preparation"></a>
#
# ### 4. Market Data Preparation
#
# The next cell loads the working dataset. The fallback is intentionally shaped like daily OHLC data so the same sequence-modelling code runs even when the live data service is unavailable.

# %%
FEATURE_COLUMNS = ["Open", "High", "Low"]
TARGET_COLUMN = "Low"
MIN_REQUIRED_ROWS = LOOKBACK_DAYS + 60


def make_synthetic_ohlc(start_date, periods=756):
    rng = np.random.default_rng(RANDOM_SEED)
    dates = pd.bdate_range(start=start_date, periods=periods)
    trend = np.linspace(0, 28, periods)
    seasonal = 4 * np.sin(np.linspace(0, 10 * np.pi, periods))
    cumulative_noise = rng.normal(0, 1.2, periods).cumsum() * 0.18
    base_price = 120 + trend + seasonal + cumulative_noise
    open_price = base_price + rng.normal(0, 1.0, periods)
    high_price = open_price + rng.uniform(0.5, 3.0, periods)
    low_price = open_price - rng.uniform(0.5, 3.0, periods)
    synthetic = pd.DataFrame(
        {"Open": open_price, "High": high_price, "Low": low_price},
        index=dates,
    )
    synthetic.index.name = "Date"
    return synthetic.round(2)


def normalise_ohlc_columns(raw_data):
    data = raw_data.copy()
    if isinstance(data.columns, pd.MultiIndex):
        for level in range(data.columns.nlevels):
            level_values = set(str(value) for value in data.columns.get_level_values(level))
            if set(FEATURE_COLUMNS).issubset(level_values):
                data.columns = data.columns.get_level_values(level)
                break
        else:
            raise ValueError("Could not identify OHLC columns in the downloaded data.")
    return data[FEATURE_COLUMNS].dropna().sort_index()


def load_market_data():
    if DATA_SOURCE_MODE not in {"auto", "live", "synthetic"}:
        raise ValueError("DATA_SOURCE_MODE must be 'auto', 'live', or 'synthetic'.")

    if DATA_SOURCE_MODE in {"auto", "live"}:
        try:
            raw_data = yf.download(
                TICKER,
                start=START_DATE,
                end=END_DATE,
                progress=False,
                auto_adjust=False,
            )
            market = normalise_ohlc_columns(raw_data)
            if len(market) < MIN_REQUIRED_ROWS:
                raise ValueError(f"Downloaded only {len(market)} usable rows.")
            market.index.name = "Date"
            return market, "live_yfinance"
        except Exception as error:
            if DATA_SOURCE_MODE == "live":
                raise
            warnings.warn(f"Using the synthetic fallback because live data was unavailable: {error}")

    return make_synthetic_ohlc(START_DATE), "synthetic_fallback"


market_data, data_source = load_market_data()
display(market_data.head())
print(f"Data source: {data_source}")
print(f"Rows: {len(market_data):,}; date range: {market_data.index.min().date()} to {market_data.index.max().date()}")

# %% [markdown]
# <a id="5-lstm-attention-dataset"></a>
#
# ### 5. LSTM-Attention Dataset
#
# The model input has shape `(samples, lookback days, features)`. Each target is the next available day's scaled `Low` value. The split below keeps the time order intact.

# %%
feature_scaler = MinMaxScaler(feature_range=(0, 1))
target_scaler = MinMaxScaler(feature_range=(0, 1))

scaled_features = feature_scaler.fit_transform(market_data[FEATURE_COLUMNS])
scaled_target = target_scaler.fit_transform(market_data[[TARGET_COLUMN]])


def build_sequences(features, target, lookback, source_frame):
    X, y, forecast_dates, naive_previous_low = [], [], [], []
    for end_position in range(lookback, len(features)):
        X.append(features[end_position - lookback : end_position])
        y.append(target[end_position, 0])
        forecast_dates.append(source_frame.index[end_position])
        naive_previous_low.append(source_frame[TARGET_COLUMN].iloc[end_position - 1])
    return (
        np.asarray(X, dtype=np.float32),
        np.asarray(y, dtype=np.float32).reshape(-1, 1),
        pd.Index(forecast_dates, name="Date"),
        np.asarray(naive_previous_low, dtype=np.float32),
    )


X, y, forecast_dates, naive_previous_low = build_sequences(
    scaled_features,
    scaled_target,
    LOOKBACK_DAYS,
    market_data,
)

split_index = int(len(X) * TRAIN_FRACTION)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]
test_dates = forecast_dates[split_index:]
naive_test_low = naive_previous_low[split_index:]

print("Training sequences:", X_train.shape)
print("Testing sequences:", X_test.shape)
print("Each sequence contains", X_train.shape[1], "days and", X_train.shape[2], "features.")

# %% [markdown]
# <a id="6-model-training-and-prediction"></a>
#
# ### 6. Model Training and Prediction
#
# The model is intentionally compact so that it can run in a practical class setting. Increase `EPOCHS` only after confirming that the baseline notebook runs successfully.

# %%
class LSTMAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim=1):
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.attention = nn.Linear(hidden_dim, 1)
        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, return_attention=False):
        lstm_output, _ = self.lstm(x)
        attention_scores = self.attention(lstm_output).squeeze(-1)
        attention_weights = torch.softmax(attention_scores, dim=1)
        context = torch.sum(lstm_output * attention_weights.unsqueeze(-1), dim=1)
        prediction = self.output_layer(context)
        if return_attention:
            return prediction, attention_weights
        return prediction


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LSTMAttention(input_dim=len(FEATURE_COLUMNS), hidden_dim=HIDDEN_DIM).to(device)
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32, device=device)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32, device=device)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32, device=device)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32, device=device)

history = []
for epoch in range(1, EPOCHS + 1):
    model.train()
    optimizer.zero_grad()
    train_prediction = model(X_train_tensor)
    train_loss = loss_function(train_prediction, y_train_tensor)
    train_loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        validation_prediction = model(X_test_tensor)
        validation_loss = loss_function(validation_prediction, y_test_tensor)

    history.append({"epoch": epoch, "train_loss": train_loss.item(), "validation_loss": validation_loss.item()})
    if epoch == 1 or epoch % 5 == 0 or epoch == EPOCHS:
        print(f"Epoch {epoch:02d}: train loss={train_loss.item():.5f}; validation loss={validation_loss.item():.5f}")

pd.DataFrame(history).tail()

# %%
model.eval()
with torch.no_grad():
    predicted_scaled, attention_weights = model(X_test_tensor, return_attention=True)

predicted_low = target_scaler.inverse_transform(predicted_scaled.cpu().numpy()).ravel()
actual_low = target_scaler.inverse_transform(y_test).ravel()

model_mse = mean_squared_error(actual_low, predicted_low)
model_rmse = model_mse ** 0.5
naive_mse = mean_squared_error(actual_low, naive_test_low)
naive_rmse = naive_mse ** 0.5

forecast_results = pd.DataFrame(
    {
        "actual_low": actual_low,
        "lstm_attention_prediction": predicted_low,
        "naive_previous_day_low": naive_test_low,
    },
    index=test_dates,
)

print(f"LSTM-attention RMSE: {model_rmse:.3f}")
print(f"Naive previous-day RMSE: {naive_rmse:.3f}")
display(forecast_results.tail())

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(forecast_results.index, forecast_results["actual_low"], label="Actual Low", linewidth=2)
ax.plot(forecast_results.index, forecast_results["lstm_attention_prediction"], label="LSTM-attention prediction")
ax.plot(forecast_results.index, forecast_results["naive_previous_day_low"], label="Naive previous-day Low", alpha=0.7)
ax.set_title(f"{TICKER} next-day Low forecast ({data_source})")
ax.set_xlabel("Date")
ax.set_ylabel("Price")
ax.legend()
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="7-attention-score-exploration"></a>
#
# ### 7. Attention Score Exploration
#
# The attention weights sum to one across the lookback window for each prediction. Larger average weights suggest that the model often used that relative day more heavily, but this does not prove that the day caused the prediction.

# %%
attention_array = attention_weights.cpu().numpy()
average_attention = attention_array.mean(axis=0)
lag_labels = [f"t-{LOOKBACK_DAYS - index}" for index in range(LOOKBACK_DAYS)]

attention_summary = pd.DataFrame(
    {
        "lag": lag_labels,
        "average_attention_weight": average_attention,
    }
)
display(attention_summary.tail())

fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(attention_summary["lag"], attention_summary["average_attention_weight"])
ax.set_title("Average attention weight by lookback day")
ax.set_xlabel("Relative day in the input sequence")
ax.set_ylabel("Average attention weight")
ax.tick_params(axis="x", rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="8-student-tasks"></a>
#
# ### 8. Student Tasks
#
# Use the completed workflow above as the baseline. Record your changes and observations in your own notebook copy.
#
# | Task | What to change | What to report |
# | --- | --- | --- |
# | A | Change `LOOKBACK_DAYS` to 10 and then 30. | Compare test RMSE and attention plots. |
# | B | Change `EPOCHS` from 20 to 5 and then 40. | Describe whether the validation loss suggests under-training or over-training. |
# | C | Set `DATA_SOURCE_MODE = "synthetic"` and rerun the notebook. | Explain how reproducible fallback data changes the interpretation of results. |
# | D | Try a different ticker if live `yfinance` data is available. | State the ticker, date range, data source, and baseline comparison. |
# | E | Inspect the five dates with the largest absolute prediction error. | Suggest one possible modelling or data reason for those errors. |

# %% [markdown]
# <a id="9-checks-and-reflection"></a>
#
# ### 9. Checks and Reflection
#
# Run the following checks after training and prediction. If a check fails, rerun the notebook from the setup cell and confirm that the data source and package setup completed successfully.

# %%
assert data_source in {"live_yfinance", "synthetic_fallback"}
assert market_data[FEATURE_COLUMNS].notna().all().all()
assert X_train.ndim == 3 and X_train.shape[1] == LOOKBACK_DAYS
assert len(forecast_results) == len(X_test)
assert np.isfinite(predicted_low).all()
assert np.isfinite(model_rmse)
assert np.allclose(attention_array.sum(axis=1), 1.0, atol=1e-5)

print("Notebook checks passed.")

# %% [markdown]
# <a id="10-reflection-and-references"></a>
#
# ### 10. Reflection and References
#
# Reflection questions:
#
# 1. Why is a chronological split more appropriate than a random split for this practical?
# 2. When would the simple previous-day baseline be difficult for a neural network to improve on?
# 3. What can attention weights show, and what can they not show?
# 4. How would you redesign the experiment if you needed a reliable forecasting study rather than a practical notebook demonstration?
#
# References:
#
# - `yfinance` documentation: https://github.com/ranaroussi/yfinance
# - PyTorch LSTM documentation: https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html
# - scikit-learn `MinMaxScaler`: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html
# - Apple ticker data are accessed through `yfinance` when available. Live financial data are used here for educational modelling practice only.
