# %% [markdown]
#     ![Cloud-First](../image/CloudFirst.png)
#
#     # SIT742: Modern Data Science
#     **(Module 05: Data Analytics)**
#
#     **Session 5B: ARIMA Forecasting**
#
#     ---
#
#     - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
#     - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
#     - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
#     - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
#     - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
#     Prepared by the SIT742 Teaching Team.
#
#     Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
#     ---
#
#     <div align="center">
#
#     <table>
#     <thead>
#     <tr>
#     <th><strong>Item</strong></th>
#     <th><strong>Description</strong></th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#     <td align="left">Module context</td>
#     <td>This notebook is one component of the practical and self-learning materials for Module 05.</td>
#     </tr>
#     <tr>
#     <td align="left">Estimated duration</td>
#     <td>Approximately 48 minutes, based on 240 minutes of M05 practical/self-learning work divided across five M05 notebooks.</td>
#     </tr>
#     <tr>
#     <td align="left">Main packages</td>
#     <td><code>pandas</code>, <code>numpy</code>, <code>matplotlib</code>, <code>statsmodels</code>, and <code>scikit-learn</code> metrics.</td>
#     </tr>
#     <tr>
#     <td align="left">Data files</td>
#     <td><code>timeseries-data.txt</code> from the public <code>Jupyter/data/</code> folder.</td>
#     </tr>
#     <tr>
#     <td align="left">Related assessment</td>
#     <td>General practical skill development; not directly assessed.</td>
#     </tr>
#     </tbody>
#     </table>
#
#     </div>
#
#     ---
#
#     **Table of Contents**
#
#     - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Data Files](#2-setup-and-data-files)
# - [3. ARIMA Concepts](#3-arima-concepts)
# - [4. Identifying d, p, and q](#4-identifying-d-p-and-q)
# - [5. Fitting and Diagnosing an ARIMA Model](#5-fitting-and-diagnosing-an-arima-model)
# - [6. Forecasting and Walk-Forward Validation](#6-forecasting-and-walk-forward-validation)
# - [7. Optional Bounded Grid Search](#7-optional-bounded-grid-search)
# - [8. Student Tasks](#8-student-tasks)
# - [9. Checks and Reflection](#9-checks-and-reflection)
# - [10. Reflection and References](#10-reflection-and-references)
#
#     ---

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# ARIMA models combine autoregression, differencing, and moving-average terms to model a time series from its own history. This practical continues with the daily births data and focuses on selecting candidate ARIMA orders, fitting a model, diagnosing residuals, and performing a small walk-forward validation.
#
# By the end of this practical, you should be able to:
#
# 1. explain the roles of `p`, `d`, and `q` in an ARIMA model;
# 2. use differencing, ACF plots, and PACF plots to propose candidate orders;
# 3. fit an ARIMA model with `statsmodels`;
# 4. inspect model residuals and forecast intervals;
# 5. run a bounded walk-forward validation without turning the notebook into a long training job.

# %% [markdown]
# <a id="2-setup-and-data-files"></a>
#
# ### 2. Setup and Data Files
#
# This notebook uses the same public SIT742 `timeseries-data.txt` file as Session 5A. Use online mode unless you are running from a cloned local SIT742 repository.

# %%
from pathlib import Path
from urllib.request import urlretrieve
import importlib.util
import subprocess
import sys
import tempfile
import warnings

PUBLIC_DATA_BASE_URL = "https://raw.githubusercontent.com/tulip-lab/sit742/develop/Jupyter/data"
EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a cloned SIT742 repository.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"


def ensure_packages_available(package_map):
    missing = [pip_name for import_name, pip_name in package_map.items() if importlib.util.find_spec(import_name) is None]
    if not missing:
        return
    if INSTALL_MISSING_PACKAGES:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *missing])
        return
    raise ModuleNotFoundError(
        "Missing required packages: "
        + ", ".join(missing)
        + ". Install them in the active environment, or set EXECUTION_MODE = 'online' to install them in an online notebook runtime."
    )


def download_public_data(required_files, prefix):
    data_dir = Path(tempfile.mkdtemp(prefix=prefix))
    downloaded_paths = {}
    for filename in required_files:
        url = f"{PUBLIC_DATA_BASE_URL}/{filename}"
        local_file = data_dir / filename
        urlretrieve(url, local_file)
        downloaded_paths[filename] = local_file
    return data_dir, downloaded_paths


def find_local_data_dir(required_files):
    cwd = Path.cwd().resolve()
    candidates = []
    for base in [cwd, *cwd.parents]:
        candidates.extend([base / "Jupyter" / "data", base / "data"])
    for candidate in candidates:
        if all((candidate / filename).exists() for filename in required_files):
            return candidate, {filename: candidate / filename for filename in required_files}
    checked = "\n".join(str(candidate) for candidate in candidates)
    raise FileNotFoundError(
        "Could not find the public SIT742 data files locally. "
        "Set EXECUTION_MODE = 'online' or run this notebook from a cloned SIT742 repository.\n"
        f"Checked:\n{checked}"
    )


def resolve_data_files(required_files, prefix):
    if EXECUTION_MODE == "online":
        return download_public_data(required_files, prefix)
    if EXECUTION_MODE == "local":
        return find_local_data_dir(required_files)
    raise ValueError("EXECUTION_MODE must be either 'online' or 'local'.")

ensure_packages_available({
    "numpy": "numpy",
    "pandas": "pandas",
    "matplotlib": "matplotlib",
    "statsmodels": "statsmodels",
    "sklearn": "scikit-learn",
})

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

warnings.filterwarnings("ignore")

required_files = ["timeseries-data.txt"]
DATA_DIR, data_files = resolve_data_files(required_files, "sit742_m05b_data_")
DataSet = data_files["timeseries-data.txt"]

df = pd.read_csv(DataSet)
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")
df = df.sort_values("Date").reset_index(drop=True)
series = df.set_index("Date")["Births"].asfreq("D")

print("Execution mode:", EXECUTION_MODE)
print("Data folder:", DATA_DIR)
print("Series length:", len(series))
series.head()

# %% [markdown]
# <a id="3-arima-concepts"></a>
#
# ### 3. ARIMA Concepts
#
# ARIMA stands for Autoregressive Integrated Moving Average.
#
# - `p`: autoregressive order. This is the number of lagged values used as predictors.
# - `d`: differencing order. This is the number of times the series is differenced to reduce non-stationarity.
# - `q`: moving-average order. This is the number of lagged forecast errors included in the model.
#
# ACF and PACF plots are diagnostic tools, not automatic decision makers. Use them with domain judgement and residual diagnostics.

# %% [markdown]
# <a id="4-identifying-d-p-and-q"></a>
#
# ### 4. Identifying d, p, and q
#
# Compare the raw, first-differenced, and second-differenced series before selecting a candidate differencing order.

# %%
first_diff = series.diff().dropna()
second_diff = first_diff.diff().dropna()

fig, axes = plt.subplots(3, 1, figsize=(12, 8), constrained_layout=True)
series.plot(ax=axes[0], title="Raw series")
first_diff.plot(ax=axes[1], title="First difference")
second_diff.plot(ax=axes[2], title="Second difference")
for ax in axes:
    ax.set_ylabel("Births")
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 7), constrained_layout=True)
plot_acf(series.dropna(), ax=axes[0, 0], lags=40)
axes[0, 0].set_title("ACF: raw series")
plot_pacf(series.dropna(), ax=axes[0, 1], lags=40, method="ywm")
axes[0, 1].set_title("PACF: raw series")
plot_acf(first_diff, ax=axes[1, 0], lags=40)
axes[1, 0].set_title("ACF: first difference")
plot_pacf(first_diff, ax=axes[1, 1], lags=40, method="ywm")
axes[1, 1].set_title("PACF: first difference")
plt.show()

# %% [markdown]
# A simple ARIMA(1, 0, 1) candidate is a useful starting point for this small teaching dataset. It is not the only defensible model; the goal is to practise the workflow and diagnostics.

# %% [markdown]
# <a id="5-fitting-and-diagnosing-an-arima-model"></a>
#
# ### 5. Fitting and Diagnosing an ARIMA Model

# %%
candidate_order = (1, 0, 1)
model = ARIMA(series, order=candidate_order)
model_fit = model.fit()
model_fit.summary()

# %%
residuals = pd.Series(model_fit.resid, index=series.index).dropna()

fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
residuals.plot(ax=axes[0], title="Residuals from ARIMA(1, 0, 1)")
axes[0].axhline(0, color="black", linewidth=1)
residuals.plot(kind="kde", ax=axes[1], title="Residual density")
plt.show()

residuals.describe()

# %% [markdown]
# Residuals should not show a strong remaining pattern. If the residual plot has structure, the model is missing some part of the time-series behaviour.

# %% [markdown]
# <a id="6-forecasting-and-walk-forward-validation"></a>
#
# ### 6. Forecasting and Walk-Forward Validation

# %%
forecast_steps = 30
forecast_result = model_fit.get_forecast(steps=forecast_steps)
forecast_mean = forecast_result.predicted_mean
forecast_ci = forecast_result.conf_int()

fig, ax = plt.subplots(figsize=(12, 5))
series.plot(ax=ax, label="Observed")
forecast_mean.plot(ax=ax, label="Forecast", color="tab:orange")
ax.fill_between(forecast_ci.index, forecast_ci.iloc[:, 0], forecast_ci.iloc[:, 1], color="tab:orange", alpha=0.2)
ax.set_title("ARIMA forecast with confidence interval")
ax.set_ylabel("Births")
ax.legend()
plt.show()

# %%
split_index = int(len(series) * 0.8)
train = series.iloc[:split_index].astype(float).tolist()
test = series.iloc[split_index:].astype(float).tolist()

history = train.copy()
predictions = []
for actual in test:
    fitted = ARIMA(history, order=candidate_order).fit()
    prediction = fitted.forecast()[0]
    predictions.append(prediction)
    history.append(actual)

rmse = mean_squared_error(test, predictions, squared=False)
validation_df = pd.DataFrame({"actual": test, "prediction": predictions}, index=series.index[split_index:])
print(f"Walk-forward RMSE: {rmse:.3f}")
validation_df.head()

# %%
validation_df.plot(figsize=(12, 5), title="Walk-forward validation: actual vs predicted")
plt.ylabel("Births")
plt.show()

# %% [markdown]
# <a id="7-optional-bounded-grid-search"></a>
#
# ### 7. Optional Bounded Grid Search
#
# Grid search can be slow because it fits many ARIMA models. The cell below is intentionally switched off by default. Enable it only when you have time to compare a small set of candidate orders.

# %%
RUN_GRID_SEARCH = False

def evaluate_arima_order(values, order):
    split = int(len(values) * 0.8)
    train_values = list(values[:split])
    test_values = list(values[split:])
    predictions = []
    for actual in test_values:
        fitted = ARIMA(train_values, order=order).fit()
        predictions.append(fitted.forecast()[0])
        train_values.append(actual)
    return mean_squared_error(test_values, predictions, squared=False)

if RUN_GRID_SEARCH:
    candidate_orders = [(p, d, q) for p in range(0, 3) for d in range(0, 2) for q in range(0, 3)]
    scores = []
    for order in candidate_orders:
        try:
            scores.append({"order": order, "rmse": evaluate_arima_order(series.astype(float).values, order)})
        except Exception as exc:
            scores.append({"order": order, "rmse": np.nan, "error": str(exc)})
    grid_results = pd.DataFrame(scores).sort_values("rmse", na_position="last")
    display(grid_results.head(10))
else:
    print("Grid search skipped. Set RUN_GRID_SEARCH = True to run a bounded comparison.")

# %% [markdown]
# <a id="8-student-tasks"></a>
#
# ### 8. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Fit one alternative ARIMA order, such as `(2, 0, 1)` or `(1, 1, 1)`.</td>
# <td>Order choice changes model complexity and residual behaviour.</td>
# <td>A model summary and one comparison with the baseline model.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Compare residual plots for two candidate orders.</td>
# <td>Residual diagnostics help detect missing pattern.</td>
# <td>Two residual plots and a short interpretation.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Run the optional grid search or manually compare three orders.</td>
# <td>Model selection should be bounded and reproducible.</td>
# <td>A compact table of candidate orders and RMSE values.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %%
# Student workspace
# alternative_order = (1, 1, 1)
# alternative_fit = ARIMA(series, order=alternative_order).fit()
# alternative_fit.summary()

# %% [markdown]
# <a id="9-checks-and-reflection"></a>
#
# ### 9. Checks and Reflection

# %%
assert len(series) > 300
assert np.isfinite(rmse)
assert len(validation_df) == len(test)
assert validation_df["prediction"].notna().all()

print("Checks passed.")
print("Candidate order:", candidate_order)
print(f"Validation RMSE: {rmse:.3f}")

# %% [markdown]
# <a id="10-reflection-and-references"></a>
#
# ### 10. Reflection and References
#
# Reflection questions:
#
# 1. Which diagnostic made you most confident or least confident in the candidate ARIMA order?
# 2. How does walk-forward validation differ from fitting once on the full series?
# 3. Why should grid search be bounded in a practical notebook?
#
# Further reading:
#
# - [statsmodels ARIMA](https://www.statsmodels.org/stable/generated/statsmodels.tsa.arima.model.ARIMA.html)
# - [statsmodels ACF and PACF plots](https://www.statsmodels.org/stable/graphics.html#time-series-plots)
# - [scikit-learn mean squared error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)
