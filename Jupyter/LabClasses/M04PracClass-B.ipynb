# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 04: Data Manipulation)**
#
# **LabClass M04B: PySpark Data Wrangling With Player Data**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find an issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# ## LabClass M04B: PySpark Data Wrangling With Player Data
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This lab class practises PySpark data wrangling and exploratory data analysis using football player skill records.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab or local Jupyter with PySpark, Java, pandas, matplotlib, and seaborn</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>A PySpark wrangling workflow, a joined pandas analysis table, and EDA figures</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development. Not directly assessed.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---

# %% [markdown]
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#m04b-overview)
# - [2. Setup and Background](#m04b-setup)
# - [3. Core Concepts](#m04b-core-concepts)
# - [4. Guided Implementation](#m04b-guided-implementation)
# - [5. Testing and Analysis](#m04b-testing)
# - [6. Student Tasks](#m04b-student-tasks)
# - [7. Reflection and References](#m04b-reflection)

# %% [markdown]
# <a id="m04b-overview"></a>
#
# ### 1. Overview and Learning Goals
#
# This lab class uses `player.parquet` to practise PySpark loading, filtering, feature scaling, joins, and exploratory visualisation.
#
# By the end of this lab, students should be able to:
#
# 1. load a public parquet file in PySpark;
# 2. inspect schema and selected summary statistics;
# 3. apply column filters and feature scaling;
# 4. join transformed columns back to the source data;
# 5. convert a bounded Spark result to pandas for visual analysis.

# %% [markdown]
# <a id="m04b-setup"></a>
#
# ### 2. Setup and Background
#
# Use **Option A** in Google Colab or another online runtime. Use **Option B** only when the SIT742 repository is cloned locally.
#
# PySpark requires a working Java and Spark runtime. If `pyspark` is missing, install it in the notebook environment before running the setup cell.

# %%
# Optional, only if your runtime does not already provide these packages.
# !pip install pyspark pyarrow pandas matplotlib seaborn

from pathlib import Path
from urllib.request import urlretrieve

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from pyspark.sql import SparkSession
from pyspark.sql import functions as F

PUBLIC_DATA_BASE = "https://raw.githubusercontent.com/tulip-lab/sit742/develop/Jupyter/data"
DATA_FILE = "player.parquet"
DOWNLOAD_DIR = Path("data") / "m04_labclasses"
LOCAL_DATA_DIRS = [
    Path("../data"),
    Path("Jupyter/data"),
    Path("SIT742/Jupyter/data"),
]

def resolve_or_download(filename):
    for data_dir in LOCAL_DATA_DIRS:
        candidate = data_dir / filename
        if candidate.exists():
            return candidate

    DOWNLOAD_DIR.mkdir(parents=True, exist_ok=True)
    target = DOWNLOAD_DIR / filename
    if not target.exists():
        urlretrieve(f"{PUBLIC_DATA_BASE}/{filename}", target)
    return target

data_path = resolve_or_download(DATA_FILE)
print("Using data file:", data_path)

spark = (
    SparkSession.builder
    .appName("SIT742-M04-LabClass-B")
    .master("local[*]")
    .getOrCreate()
)

# %% [markdown]
# <a id="m04b-core-concepts"></a>
#
# ### 3. Core Concepts
#
# Parquet is a columnar file format often used in distributed data systems. In this lab, Spark handles the parquet file and then a bounded pandas DataFrame is used for plotting.
#
# Key workflow:
#
# 1. read parquet into a Spark DataFrame;
# 2. inspect schema and filter rows;
# 3. create scaled features;
# 4. join transformed columns using a generated row identifier;
# 5. convert only the needed result to pandas for EDA.

# %% [markdown]
# <a id="m04b-guided-implementation"></a>
#
# ### 4. Guided Implementation
#
# First read the parquet file and inspect the schema. The expected dataset size is approximately 18159 rows and 32 columns.

# %%
spark_df = spark.read.parquet(str(data_path.resolve()))
print("Rows:", spark_df.count())
print("Columns:", len(spark_df.columns))
spark_df.printSchema()
spark_df.show(5, truncate=False)

# %%
filtered_df = spark_df.filter(F.col("BallControl") > 50)
range_df = spark_df.filter(
    (F.col("BallControl") > 50)
    & (F.col("BallControl") < 70)
)
other_df = spark_df.filter(F.col("LongPassing") > 60)

print("Rows where BallControl > 50:", filtered_df.count())
print("Rows where BallControl is between 50 and 70:", range_df.count())
print("Rows where LongPassing is greater than 60:", other_df.count())

range_df.select("BallControl").describe().show()
other_df.select("BallControl").describe().show()

# %%
indexed_df = spark_df.withColumn("row_id", F.monotonically_increasing_id())

stats = indexed_df.select(
    F.min("Height(CM)").alias("min_value"),
    F.max("Height(CM)").alias("max_value"),
    F.mean("Height(CM)").alias("mean_value"),
    F.stddev_samp("Height(CM)").alias("std_value"),
).first()

denominator = stats["max_value"] - stats["min_value"]
if denominator == 0:
    raise ValueError("Cannot min-max scale a constant column.")

scaled_df = indexed_df.withColumn(
    "scaled_height",
    (F.col("Height(CM)") - F.lit(stats["min_value"])) / F.lit(denominator),
).withColumn(
    "standardized_height",
    (F.col("Height(CM)") - F.lit(stats["mean_value"])) / F.lit(stats["std_value"]),
)

df_stand = scaled_df.select(
    "row_id",
    "Height(CM)",
    "scaled_height",
    "standardized_height",
)

joined_df = indexed_df.join(
    df_stand.select("row_id", "scaled_height", "standardized_height"),
    on="row_id",
    how="inner",
)

dataframe_pd = joined_df.toPandas()
dataframe_pd[["Height(CM)", "scaled_height", "standardized_height"]].head()

# %%
BIN_COLUMNS = ['LongPassing', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions']
for column in BIN_COLUMNS:
    if column in dataframe_pd.columns:
        dataframe_pd[f"{column}_band"] = pd.cut(
            dataframe_pd[column],
            bins=3,
            labels=["low", "medium", "high"],
            include_lowest=True,
        )

fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(dataframe_pd["Height(CM)"], kde=True, ax=axes[0])
axes[0].set_title("Distribution of Height(CM)")

if "LongPassing_band" in dataframe_pd.columns:
    sns.countplot(data=dataframe_pd, x="LongPassing_band", ax=axes[1])
    axes[1].tick_params(axis="x", rotation=45)
    axes[1].set_title("Count by LongPassing_band")
plt.tight_layout()
plt.show()

plot_data = dataframe_pd[dataframe_pd["LongPassing_band"].notna()].copy()
heatmap_counts = (
    plot_data
    .groupby(["LongPassing_band", "Acceleration_band"], observed=True)
    .size()
    .unstack(fill_value=0)
)

plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_counts, cmap="Blues")
plt.title("Count heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="m04b-testing"></a>
#
# ### 5. Testing and Analysis
#
# Run these checks before interpreting the EDA figures.

# %%
assert spark_df.count() > 0
assert "Height(CM)" in dataframe_pd.columns
assert "scaled_height" in dataframe_pd.columns
assert dataframe_pd["scaled_height"].between(0, 1).all()
assert dataframe_pd["standardized_height"].notna().all()
assert len(dataframe_pd) == spark_df.count()

print("M04B checks passed.")

# %% [markdown]
# <a id="m04b-student-tasks"></a>
#
# ### 6. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Change the filter threshold for `BallControl` and compare row counts.</td>
# <td>Shows how Spark filters affect distributed datasets.</td>
# <td>Two row counts and a short interpretation.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Scale one additional numeric column.</td>
# <td>Practises extending a transformation workflow.</td>
# <td>A new scaled column and a range check.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Create one additional grouped visualisation.</td>
# <td>Connects wrangling decisions to EDA.</td>
# <td>A plot and a written explanation of what it shows.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %%
# TODO: Complete Task 1 to Task 3 here.
# Keep transformations small enough to run in your current notebook runtime.

# %% [markdown]
# <a id="m04b-reflection"></a>
#
# ### 7. Reflection and References
#
# Reflection questions:
#
# 1. Why is parquet a useful format for distributed processing?
# 2. When should you avoid converting a Spark DataFrame to pandas?
# 3. Which part of this workflow is most sensitive to runtime setup?
#
# #### Further Readings
#
# - PySpark DataFrame API: https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/dataframe.html
# - Apache Parquet documentation: https://parquet.apache.org/docs/
# - seaborn visualisation documentation: https://seaborn.pydata.org/
