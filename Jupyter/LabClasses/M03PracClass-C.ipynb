# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 03: Big Data)**
#
# **LabClass M03C: Citation snapshots, SQL-style summaries, and web-data risk**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find an issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# ## LabClass M03C: Citation snapshots, SQL-style summaries, and web-data risk
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This lab class is the C stream practical demonstration for Module 03. It uses public citation snapshot CSV files to practise repeatable web-data workflows without requiring live browser automation.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab or local Jupyter with pandas, NumPy, and the listed optional packages.</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>A cleaned citation snapshot workflow, SQL-style and pandas summaries, citation bands, encoded features, and a bounded nearest-neighbour summary.</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development. Not directly assessed.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---

# %% [markdown]
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1.-overview-and-learning-goals)
# - [2. Setup and Data Files](#2.-setup-and-data-files)
# - [3. Snapshot-First Web Data Workflow](#3.-snapshot-first-web-data-workflow)
# - [4. Load and Clean Citation Data](#4.-load-and-clean-citation-data)
# - [5. Dictionary Filtering and JSON Output](#5.-dictionary-filtering-and-json-output)
# - [6. SQL-Style and pandas ETL](#6.-sql-style-and-pandas-etl)
# - [7. One-Hot Encoding and Distance Matrix](#7.-one-hot-encoding-and-distance-matrix)
# - [8. Student Tasks](#8.-student-tasks)
# - [9. Checks](#9.-checks)
# - [10. Reflection and References](#10.-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
# ### 1. Overview and Learning Goals
#
# This practical uses public snapshot CSV files for Deakin professor names and citation metrics. Older versions of this exercise used live browser automation. The routine teaching path now starts from public snapshots so the notebook is repeatable in Colab and local Jupyter.
#
# By the end of this lab, students should be able to:
#
# 1. explain why live scraping can be fragile;
# 2. load and clean snapshot CSV data;
# 3. convert text columns to numeric fields safely;
# 4. compare SQL-style aggregation with pandas `groupby`;
# 5. create citation bands and one-hot encoded features; and
# 6. compute a small nearest-neighbour summary.

# %% [markdown]
# <a id="2-setup-and-data-files"></a>
# ### 2. Setup and Data Files
#
# This notebook uses `Professor_name_list.csv` and `Professor_citation_informaton.csv`.
#
# The filename `Professor_citation_informaton.csv` keeps the spelling used in the public data folder.

# %%
from pathlib import Path
from urllib.request import urlretrieve
import json
import sys
import tempfile

import numpy as np
import pandas as pd

PUBLIC_DATA_BASE_URL = "https://raw.githubusercontent.com/tulip-lab/sit742/develop/Jupyter/data"
EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a cloned SIT742 repository.

OUTPUT_DIR = Path(tempfile.mkdtemp(prefix="sit742_m03c_output_"))
required_files = ['Professor_name_list.csv', 'Professor_citation_informaton.csv']


def download_public_data(required_files):
    data_dir = Path(tempfile.mkdtemp(prefix="sit742_m03c_data_"))
    downloaded_paths = {}
    for filename in required_files:
        local_file = data_dir / filename
        urlretrieve(f"{PUBLIC_DATA_BASE_URL}/{filename}", local_file)
        downloaded_paths[filename] = local_file
    return data_dir, downloaded_paths


def find_local_data_dir(required_files):
    candidates = [
        Path.cwd() / "Jupyter" / "data",
        Path.cwd() / "data",
        Path.cwd().parent / "data",
        Path.cwd().parent.parent / "Jupyter" / "data",
    ]
    for candidate in candidates:
        if all((candidate / filename).exists() for filename in required_files):
            return candidate
    searched = "\n".join(str(candidate) for candidate in candidates)
    raise FileNotFoundError("Could not find the SIT742 public data folder. Searched:\n" + searched)


if EXECUTION_MODE == "online":
    DATA_DIR, data_paths_by_file = download_public_data(required_files)
elif EXECUTION_MODE == "local":
    DATA_DIR = find_local_data_dir(required_files)
    data_paths_by_file = {filename: DATA_DIR / filename for filename in required_files}
else:
    raise ValueError('EXECUTION_MODE must be "online" or "local".')

print("Python:", sys.version.split()[0])
print("pandas:", pd.__version__)
print("Data folder:", DATA_DIR)
print("Output folder:", OUTPUT_DIR)

# %%
try:
    from pandasql import sqldf
except ImportError:
    sqldf = None
    print("pandasql is optional and is not installed; pandas equivalents will still run.")

names_path = data_paths_by_file["Professor_name_list.csv"]
citations_path = data_paths_by_file["Professor_citation_informaton.csv"]
print("Names CSV:", names_path)
print("Citation CSV:", citations_path)

# %% [markdown]
# <a id="3-snapshot-first-web-data-workflow"></a>
# ### 3. Snapshot-First Web Data Workflow
#
# Live web pages and search results can change without notice, block automation, or return different structures across environments. For routine learning, start from a stable snapshot, then discuss what a live collection workflow would need to validate.

# %%
RUN_LIVE_COLLECTION = False

if RUN_LIVE_COLLECTION:
    print("Live collection is disabled in this public practical. Discuss current site rules, robots policy, and runtime setup before enabling any live collection workflow.")
else:
    print("Routine mode: using public snapshot CSV files.")

# %% [markdown]
# <a id="4-load-and-clean-citation-data"></a>
# ### 4. Load and Clean Citation Data

# %%
names_df = pd.read_csv(names_path, index_col=0)
citations_raw = pd.read_csv(citations_path, index_col=0)

metric_columns = [
    "citation_all",
    "citation_since2016",
    "h-index_all",
    "h-index_since2016",
    "i10-index_all",
    "i10-index_since2016",
]

citations = citations_raw.copy()
for column in metric_columns:
    citations[column] = pd.to_numeric(citations[column], errors="coerce")

citations_clean = citations.dropna(subset=["citation_all"]).reset_index(drop=True)
print("Names rows:", len(names_df))
print("Citation rows before cleaning:", len(citations_raw))
print("Citation rows after cleaning:", len(citations_clean))
citations_clean.head()

# %% [markdown]
# <a id="5-dictionary-filtering-and-json"></a>
# ### 5. Dictionary Filtering and JSON Output

# %%
citation_dict = citations_clean.to_dict(orient="list")
for key, values in citation_dict.items():
    unique_count = pd.Series(values).nunique(dropna=False)
    print(f"{key}: {len(values)} values, {unique_count} unique values")

citation_mask = (citations_clean["citation_all"] > 3000) & (citations_clean["citation_all"] < 10000)
citation_filtered = citations_clean.loc[citation_mask].reset_index(drop=True)
citation_json_path = OUTPUT_DIR / "citation_3000_to_10000.json"
citation_filtered.to_json(citation_json_path, orient="records", indent=2)
df_citation = pd.read_json(citation_json_path)

print("Filtered rows:", len(df_citation))
df_citation.head()

# %% [markdown]
# <a id="6-sql-style-and-pandas-etl"></a>
# ### 6. SQL-Style and pandas ETL

# %%
if sqldf is not None:
    query1 = sqldf("SELECT * FROM df_citation LIMIT 10", {"df_citation": df_citation})
    query3 = sqldf(
        """
        SELECT Title,
               AVG(citation_all) AS avg_citation_all,
               AVG(citation_since2016) AS avg_citation_since2016
        FROM df_citation
        GROUP BY Title
        ORDER BY avg_citation_all DESC
        """,
        {"df_citation": df_citation},
    )
else:
    query1 = df_citation.head(10)
    query3 = None

query1

# %%
def label_citation(series):
    return pd.cut(
        series,
        bins=[0, 4000, 4300, 7500, float("inf")],
        labels=["low", "medium", "good", "excellent"],
        include_lowest=True,
    )


df_grouped = (
    df_citation[["Name", "Title", "citation_all", "citation_since2016"]]
    .groupby(["Name", "Title"], as_index=False)
    .mean()
    .sort_values(["Title", "Name"])
)
df_grouped["citation band"] = label_citation(df_grouped["citation_all"])

title_summary = (
    df_citation.groupby("Title", as_index=False)[["citation_all", "citation_since2016"]]
    .mean()
    .sort_values("citation_all", ascending=False)
)

title_summary

# %% [markdown]
# <a id="7-one-hot-and-distance"></a>
# ### 7. One-Hot Encoding and Distance Matrix

# %%
num_col = df_grouped.select_dtypes(include=np.number).columns
cat_col = df_grouped.select_dtypes(exclude=np.number).columns

df_num = df_grouped[num_col]
df_cat = df_grouped[cat_col]
df_onehot = pd.get_dummies(df_cat, dtype=int)
df_all = pd.concat([df_num.reset_index(drop=True), df_onehot.reset_index(drop=True)], axis=1)

print("Prepared feature shape:", df_all.shape)
df_all.head()

# %%
def distance_to_one(row1, row2):
    return np.sqrt(np.sum(np.square(row1 - row2)))


def distance_to_many(row1, rows):
    return np.sqrt(np.sum(np.square(rows - row1), axis=1))


def nearest_neighbour_summary(frame, sample_size=100):
    sample = frame.head(sample_size).to_numpy(dtype=float)
    distance_matrix = np.vstack([distance_to_many(row, sample) for row in sample])
    nearest = []
    for index, distances in enumerate(distance_matrix):
        order = np.argsort(distances)
        nearest.append(order[1] if len(order) > 1 else order[0])
    return distance_matrix, pd.DataFrame({"index": range(len(nearest)), "most_similar_index": nearest})

# %%
distance_matrix, nearest = nearest_neighbour_summary(df_all, sample_size=min(100, len(df_all)))
nearest_named = nearest.assign(
    Name=df_grouped.loc[nearest["index"], "Name"].to_numpy(),
    Most_similar_name=df_grouped.loc[nearest["most_similar_index"], "Name"].to_numpy(),
)

print("Distance matrix shape:", distance_matrix.shape)
nearest_named.head(10)

# %% [markdown]
# <a id="8-student-tasks"></a>
# ### 8. Student Tasks
#
# 1. Change the citation filter to `citation_all >= 1000` and report the row count.
# 2. Compare the title-level summary from SQL-style logic and pandas logic.
# 3. Add a band for `citation_since2016`.
# 4. Identify which columns should not be interpreted as current live citation values.
# 5. Explain one ethical or operational risk of live collection from public profile pages.

# %%
# Task workspace.
citation_1000_plus = citations_clean.loc[citations_clean["citation_all"] >= 1000]
print("Rows with citation_all >= 1000:", len(citation_1000_plus))
print(title_summary)

# %% [markdown]
# <a id="9-checks"></a>
# ### 9. Checks

# %%
assert len(names_df) > 0
assert len(citations_clean) > 0
assert citation_json_path.exists()
assert df_citation["citation_all"].between(3000, 10000, inclusive="neither").all()
assert df_grouped["citation band"].notna().all()
assert distance_matrix.shape[0] == distance_matrix.shape[1]

print("M03PracClass-C checks passed.")

# %% [markdown]
# <a id="10-reflection-and-references"></a>
# ### 10. Reflection and References
#
# Reflection prompts:
#
# 1. Why is a stable snapshot useful for teaching web-data workflows?
# 2. What checks would you need before trusting a live scrape?
# 3. Why should citation metrics be interpreted carefully?
#
# References:
#
# - pandas documentation: `read_csv`, `to_numeric`, `groupby`, `cut`, `get_dummies`
# - Python documentation: JSON data handling
# - Website terms of use and robots policies should be checked before live collection
