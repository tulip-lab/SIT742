# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 06: Advanced)**
#
# **Session 6B: Differentially Private Exploratory Data Analysis**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, privacy-aware analytics, and applied machine learning.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for Module 06.</td>
# </tr>
# <tr>
# <td align="left">Estimated duration</td>
# <td>Approximately 48 minutes, based on 240 minutes of M06 practical/self-learning work across five notebooks.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab or local Jupyter with Python packages and internet access for the Covertype dataset, or the synthetic fallback.</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>Differentially private histograms, summary queries, and privacy-budget accounting.</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development; not directly assessed.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---
#
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup, Packages, and Data Source](#2-setup-packages-and-data-source)
# - [3. Background Concepts](#3-background-concepts)
# - [4. Guided Example: Private Exploration](#4-guided-example-private-exploration)
# - [5. Practical Exercise: Private Summary Queries](#5-practical-exercise-private-summary-queries)
# - [6. Student Tasks](#6-student-tasks)
# - [7. Checks, Reflection, and References](#7-checks-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# Exploratory data analysis often asks many small questions about a dataset. Differential privacy changes this workflow because every private query spends part of the privacy budget. In this practical you will use `diffprivlib` to create private histograms and summary statistics while tracking the cumulative privacy spend.
#
# The notebook preserves the original IBM diffprivlib Covertype exploration flow, but bounds the default sample size and includes a synthetic fallback for environments where the Covertype fetch is unavailable.
#
# By the end of this practical, you should be able to:
#
# 1. initialise and inspect a `diffprivlib` privacy budget accountant;
# 2. load or simulate a Covertype-like dataset for private EDA practice;
# 3. create differentially private histograms and 2D histograms;
# 4. run private summary queries such as mean, variance, and counts;
# 5. explain how repeated queries consume the privacy budget.

# %% [markdown]
# <a id="2-setup-packages-and-data-source"></a>
#
# ### 2. Setup, Packages, and Data Source
#
# This notebook uses the Covertype dataset through `sklearn.datasets.fetch_covtype`. That fetch may require internet access and may be slow on first use.
#
# #### Option A: Google Colab / online execution
#
# Keep `EXECUTION_MODE = "online"` and `DATA_SOURCE_MODE = "auto"`. Missing packages are installed into the temporary runtime. If the Covertype fetch fails, the notebook uses a reproducible synthetic fallback so the code flow can still be practised.
#
# #### Option B: Local repository execution
#
# Use `EXECUTION_MODE = "local"` only when your local Python environment already has the required packages installed. Local mode does not install packages automatically. You may set `DATA_SOURCE_MODE = "synthetic"` when you need an offline practice run.

# %%
from pathlib import Path
import importlib.util
import subprocess
import sys
import warnings

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a managed local environment.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"
RANDOM_STATE = 742
DATA_SOURCE_MODE = "auto"  # Use "auto", "fetch_covtype", or "synthetic".
MAX_EXAMPLES = 20000

PACKAGE_SPECS = [
    "diffprivlib",
    "scikit-learn<1.8",
    "matplotlib",
    "pandas",
]


def version_prefix(version, length=2):
    parts = []
    for part in version.split(".")[:length]:
        digits = "".join(char for char in part if char.isdigit())
        parts.append(int(digits) if digits else 0)
    while len(parts) < length:
        parts.append(0)
    return tuple(parts)


def scikit_learn_is_compatible():
    if importlib.util.find_spec("sklearn") is None:
        return False
    import sklearn
    return version_prefix(sklearn.__version__) < (1, 8)


def ensure_packages_available():
    import_map = {
        "diffprivlib": "diffprivlib",
        "sklearn": "scikit-learn<1.8",
        "matplotlib": "matplotlib",
        "pandas": "pandas",
    }
    missing = [
        pip_name
        for import_name, pip_name in import_map.items()
        if importlib.util.find_spec(import_name) is None
    ]
    incompatible = []
    if not scikit_learn_is_compatible():
        incompatible.append("scikit-learn<1.8")
    if not missing and not incompatible:
        return
    if INSTALL_MISSING_PACKAGES:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *PACKAGE_SPECS])
        return
    raise ModuleNotFoundError(
        "Missing or incompatible required packages: "
        + ", ".join(sorted(set(missing + incompatible)))
        + ". Install them in the active environment, or set EXECUTION_MODE = 'online' to install them in an online notebook runtime."
    )


ensure_packages_available()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import diffprivlib as dp
from sklearn.datasets import fetch_covtype

print("Setup complete.")
print("Current working directory:", Path.cwd())

# %% [markdown]
# The loader below keeps the public teaching workflow reproducible:
#
# - it tries `fetch_covtype()` when available;
# - it limits the working sample to `MAX_EXAMPLES` rows so plots remain responsive;
# - it uses a labelled synthetic fallback only for code-flow practice when the real dataset cannot be fetched.

# %%
def make_synthetic_covtype_like(n_rows=5000, random_state=RANDOM_STATE):
    rng = np.random.default_rng(random_state)
    elevation = rng.normal(2600, 450, size=n_rows).clip(1000, 4000)
    aspect = rng.uniform(0, 360, size=n_rows)
    slope = rng.integers(0, 67, size=n_rows)
    h_hydrology = rng.gamma(2.0, 140.0, size=n_rows).clip(0, 1000)
    v_hydrology = rng.normal(35, 95, size=n_rows).clip(0, 1000)
    h_roadways = rng.gamma(2.4, 900.0, size=n_rows).clip(10, 10000)
    hillshade_9 = rng.integers(0, 256, size=n_rows)
    hillshade_noon = rng.integers(0, 256, size=n_rows)
    hillshade_3 = rng.integers(0, 256, size=n_rows)
    h_fire = rng.gamma(2.2, 700.0, size=n_rows).clip(10, 10000)
    numeric = np.column_stack([
        elevation,
        aspect,
        slope,
        h_hydrology,
        v_hydrology,
        h_roadways,
        hillshade_9,
        hillshade_noon,
        hillshade_3,
        h_fire,
    ])
    wilderness_index = rng.integers(0, 4, size=n_rows)
    soil_index = rng.integers(0, 40, size=n_rows)
    wilderness_one_hot = np.eye(4)[wilderness_index]
    soil_one_hot = np.eye(40)[soil_index]
    labels = rng.integers(1, 8, size=n_rows)
    return np.hstack([numeric, wilderness_one_hot, soil_one_hot]).astype(float), labels


def load_covtype_raw_data(mode=DATA_SOURCE_MODE):
    if mode not in {"auto", "fetch_covtype", "synthetic"}:
        raise ValueError("DATA_SOURCE_MODE must be 'auto', 'fetch_covtype', or 'synthetic'.")

    if mode in {"auto", "fetch_covtype"}:
        try:
            dataset = fetch_covtype()
            return dataset.data, dataset.target, "sklearn fetch_covtype"
        except Exception as exc:
            if mode == "fetch_covtype":
                raise
            warnings.warn(
                "Could not fetch the Covertype dataset. Using a reproducible synthetic fallback for code-flow practice only. "
                f"Original error: {exc}"
            )

    data, labels = make_synthetic_covtype_like()
    return data, labels, "synthetic fallback"


def collapse_covtype_one_hot_columns(raw_data):
    return np.concatenate((
        raw_data[:, :-44],
        (raw_data[:, -44:-40] * np.arange(0, 4)).sum(axis=1)[:, np.newaxis],
        (raw_data[:, -40:] * np.arange(0, 40)).sum(axis=1)[:, np.newaxis],
    ), axis=1)


raw_data, labels, data_source = load_covtype_raw_data(DATA_SOURCE_MODE)

if raw_data.shape[0] > MAX_EXAMPLES:
    rng = np.random.default_rng(RANDOM_STATE)
    selected_rows = rng.choice(raw_data.shape[0], size=MAX_EXAMPLES, replace=False)
    raw_data = raw_data[selected_rows]
    labels = labels[selected_rows]

data = collapse_covtype_one_hot_columns(raw_data)
n_examples = data.shape[0]

print("Data source:", data_source)
print("Rows used:", n_examples)
print("Columns after encoding collapse:", data.shape[1])

# %% [markdown]
# <a id="3-background-concepts"></a>
#
# ### 3. Background Concepts
#
# Private exploratory analysis needs two habits that are less visible in ordinary EDA:
#
# - **Declare public ranges before querying.** Histogram and summary mechanisms need bounds or ranges to calibrate noise.
# - **Track cumulative privacy spend.** Each private query spends budget; repeated exploration is not free.
#
# The Covertype data has numeric measurements plus one-hot encoded wilderness and soil categories. The next cell collapses those one-hot groups into compact numeric columns for plotting.

# %%
col_names = [
    "Elevation",
    "Aspect",
    "Slope",
    "H-Distance To Hydrology",
    "V-Distance To Hydrology",
    "H-Distance To Roadways",
    "Hillshade 9am",
    "Hillshade Noon",
    "Hillshade 3pm",
    "H-Distance To Fire Points",
    "Wilderness Area",
    "Soil Type",
]

ranges = [
    (1000.0, 4000.0),
    (0, 360),
    (0, 66),
    (0, 1000.0),
    (0, 1000.0),
    (10, 10000.0),
    (0, 255),
    (0, 255),
    (0, 255),
    (10, 10000.0),
    (0, 3),
    (0, 39),
]

assert len(col_names) == len(ranges)

pd.DataFrame({"feature": col_names, "public_range": ranges})

# %% [markdown]
# Create a privacy accountant. Rerun this cell if you want to restart the private-query sequence from a fresh budget.

# %%
def reset_privacy_accountant(total_epsilon=1.0, delta=0.0):
    accountant = dp.BudgetAccountant(total_epsilon, delta)
    accountant.set_default()
    return accountant


acc = reset_privacy_accountant(total_epsilon=1.0, delta=0.0)
eps = 0.04

print("Privacy accountant:", acc)
print("Default query epsilon:", eps)

# %% [markdown]
# <a id="4-guided-example-private-exploration"></a>
#
# ### 4. Guided Example: Private Exploration
#
# Start with a differentially private histogram of the cover-type labels. The values are noisy proportions rather than exact counts.

# %%
label_hist, label_bins = dp.tools.histogram(labels, epsilon=eps, bins=7, range=(1, 8))

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(np.arange(1, 8), label_hist / n_examples)
ax.set_title("Differentially private label proportions")
ax.set_xlabel("Cover type")
ax.set_ylabel("Noisy proportion")
ax.set_ylim(0, max(0.05, (label_hist / n_examples).max() * 1.15))
plt.show()

pd.DataFrame({
    "cover_type": np.arange(1, 8),
    "noisy_proportion": label_hist / n_examples,
})

# %% [markdown]
# Next, create private histograms for each feature. Notice that this spends additional privacy budget because each histogram is a private query.

# %%
fig, axs = plt.subplots(3, 4, sharey=True, figsize=(16, 11))
fig.subplots_adjust(hspace=0.35)

for feature_index, feature_name in enumerate(col_names):
    ax = axs.flat[feature_index]
    ax.set_title(feature_name)
    feature_range = ranges[feature_index]
    n_bins = 10

    if feature_index >= 10:
        feature_range = (0, feature_range[1] + 1)
        n_bins = int(feature_range[1])

    bar_width = (feature_range[1] - feature_range[0]) / n_bins * 0.9
    hist, bins = dp.tools.histogram(
        data[:, feature_index],
        bins=n_bins,
        range=feature_range,
        epsilon=eps,
    )
    ax.bar(bins[:-1] + np.diff(bins), hist / n_examples, width=bar_width)
    ax.set_ylim(0, 1)

plt.show()

print("Privacy spend after initial histograms:", acc.total())
print("Queries recorded:", len(acc))

# %% [markdown]
# Two-dimensional histograms let us explore how a feature varies by cover type. These are still private queries and still spend budget.

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
n_bins = 10
selected_columns = (1, 3, 8)

for plot_index, col in enumerate(selected_columns):
    ax = axs.flat[plot_index]
    ax.set_title(col_names[col])
    width = (ranges[col][1] - ranges[col][0]) / n_bins * 0.9

    hist, bins, _ = dp.tools.histogram2d(
        data[:, col],
        labels,
        epsilon=eps,
        bins=(n_bins, 7),
        range=(ranges[col], (1, 8)),
    )
    cumulative = np.zeros_like(hist[:, 0])

    for label_index in range(hist.shape[1]):
        ax.bar(
            bins[:-1] + np.diff(bins),
            hist[:, label_index] / n_examples,
            bottom=cumulative,
            label=str(label_index + 1),
            width=width,
        )
        cumulative += hist[:, label_index] / n_examples

ax.legend(title="Cover type")
plt.show()

# %% [markdown]
# This heat-map style view shows the private joint distribution of two numeric features.

# %%
col1, col2 = (1, 3)

hist, bins_y, bins_x = dp.tools.histogram2d(
    data[:, col1],
    data[:, col2],
    epsilon=eps,
    range=(ranges[col1], ranges[col2]),
)

fig, ax = plt.subplots(figsize=(6, 4.5))
mesh = ax.pcolormesh(bins_y, bins_x, hist / n_examples, cmap="Blues")
ax.set_ylabel(col_names[col1])
ax.set_xlabel(col_names[col2])
ax.set_title("Private 2D histogram")
fig.colorbar(mesh, ax=ax)
plt.show()

# %% [markdown]
# <a id="5-practical-exercise-private-summary-queries"></a>
#
# ### 5. Practical Exercise: Private Summary Queries
#
# Private summary functions are useful when you need a numeric result rather than a plot. Interpret them as noisy answers, not exact dataset facts.

# %%
label_one_mask = labels == 1

statistics_records = [
    {
        "query": "Mean elevation",
        "value": dp.tools.mean(data[:, 0], bounds=ranges[0], epsilon=eps),
    },
    {
        "query": "Elevation variance",
        "value": dp.tools.var(data[:, 0], bounds=ranges[0], epsilon=eps),
    },
    {
        "query": "Share with elevation at least 3000",
        "value": dp.tools.count_nonzero(data[:, 0] >= 3000, epsilon=eps) / n_examples,
    },
]

if label_one_mask.any():
    statistics_records.append({
        "query": "Mean elevation for cover type 1",
        "value": dp.tools.mean(data[label_one_mask, 0], bounds=ranges[0], epsilon=eps),
    })

dp_statistics = pd.DataFrame(statistics_records)
dp_statistics

# %% [markdown]
# <a id="6-student-tasks"></a>
#
# ### 6. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Choose one feature and create an additional private histogram with a smaller or larger `epsilon`.</td>
# <td>Changing `epsilon` changes the noise in the private output.</td>
# <td>A plot plus one sentence comparing the result.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Record the privacy spend before and after an extra query.</td>
# <td>Repeated EDA consumes cumulative privacy budget.</td>
# <td>The two accountant outputs and a short interpretation.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Explain one public range assumption from the feature table.</td>
# <td>Ranges affect both privacy calibration and visual interpretation.</td>
# <td>A short written explanation naming the feature and range.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# Use the commented workspace below if you want to try an extra feature histogram. If the accountant budget is exhausted, rerun the accountant setup cell before experimenting.

# %%
# Student workspace
# student_feature = 0
# student_epsilon = 0.02
# student_hist, student_bins = dp.tools.histogram(
#     data[:, student_feature],
#     bins=10,
#     range=ranges[student_feature],
#     epsilon=student_epsilon,
# )
# plt.bar(student_bins[:-1] + np.diff(student_bins), student_hist / n_examples)
# plt.title(f"Private histogram: {col_names[student_feature]}")
# plt.show()

# %% [markdown]
# <a id="7-checks-reflection-and-references"></a>
#
# ### 7. Checks, Reflection, and References
#
# Use these checks to confirm that the private exploration state is coherent.

# %%
assert data.shape[1] == len(col_names)
assert n_examples <= MAX_EXAMPLES
assert labels.min() >= 1
assert labels.max() <= 7
assert len(acc) > 0

print("Checks passed.")
print("Data source:", data_source)
print("Rows used:", n_examples)
print("Total privacy spend:", acc.total())
print("Remaining privacy budget:", acc.remaining())

# %% [markdown]
# Reflection questions:
#
# 1. Which query used the privacy budget most visibly in this notebook?
# 2. Why is exploratory analysis harder when every query spends budget?
# 3. When would a synthetic fallback be useful, and when would it be misleading?
#
# Further reading:
#
# - [IBM Differential Privacy Library](https://github.com/IBM/differential-privacy-library)
# - [diffprivlib tools documentation](https://diffprivlib.readthedocs.io/en/latest/modules/tools.html)
# - [diffprivlib privacy accountant documentation](https://diffprivlib.readthedocs.io/en/latest/modules/accountant.html)
# - [scikit-learn Covertype dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_covtype.html)
#
# Dataset note: the preferred data source is the Covertype dataset fetched by `scikit-learn`. The synthetic fallback is for notebook code-flow practice only and should not be used for real data claims.
