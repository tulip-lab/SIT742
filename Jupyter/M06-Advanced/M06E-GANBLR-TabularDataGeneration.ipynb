# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 06: Advanced)**
#
# **Session 6E: GANBLR for Tabular Data Generation**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, privacy-aware analytics, generative modelling, and applied machine learning.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for Module 06.</td>
# </tr>
# <tr>
# <td align="left">Estimated duration</td>
# <td>Approximately 48 minutes, based on 240 minutes of M06 practical/self-learning work across five notebooks.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab or local Jupyter with GANBLR, TensorFlow, pandas, scikit-learn, Matplotlib, NetworkX, and related dependencies.</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>A bounded tabular synthetic-data workflow using GANBLR where available, plus distribution and TSTR/TRTR checks.</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development; not directly assessed.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---
#
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Required Packages](#2-setup-and-required-packages)
# - [3. Background Concepts](#3-background-concepts)
# - [4. Guided Example: Generate Tabular Data](#4-guided-example-generate-tabular-data)
# - [5. Practical Exercise: Evaluate Synthetic Tabular Data](#5-practical-exercise-evaluate-synthetic-tabular-data)
# - [6. Student Tasks](#6-student-tasks)
# - [7. Reflection and References](#7-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# Tabular data generation creates synthetic rows and columns that resemble the structure of a real dataset. This is useful for data augmentation, testing, demonstration, and privacy-aware data sharing, but generated data still needs careful evaluation.
#
# In this practical you will use GANBLR, a tabular data generation model, on the built-in discrete Adult demo dataset when the package is available. The notebook also includes a clearly labelled teaching fallback so the code-flow can still be practised if the GANBLR install is unavailable in a notebook runtime.
#
# By the end of this practical, you should be able to:
#
# 1. explain why tabular data generation differs from image generation;
# 2. describe how Bayesian-network ideas can support tabular generation;
# 3. fit a bounded GANBLR tabular generator where the package is available;
# 4. sample synthetic rows and compare simple real and synthetic distributions;
# 5. interpret TSTR and TRTR evaluation results cautiously.

# %% [markdown]
# <a id="2-setup-and-required-packages"></a>
#
# ### 2. Setup and Required Packages
#
# This notebook uses the public `ganblr` package and its built-in discrete Adult demo dataset. The package may install TensorFlow and `pgmpy`, so the first online run can take time.
#
# #### Option A: Google Colab / online execution
#
# Keep `EXECUTION_MODE = "online"`. Missing packages are installed into the temporary runtime. If `ganblr==0.1.3` cannot be installed, the setup cell tries the public GitHub package fallback. If both fail, the notebook uses a labelled teaching fallback for code-flow practice.
#
# #### Option B: Local repository execution
#
# Use `EXECUTION_MODE = "local"` only when your local Python environment already has the required packages installed. Local mode raises a clear error instead of changing your environment automatically.
#
# Runtime controls:
#
# - `TABULAR_TRAINING_PRESET = "quick"`: bounded default run.
# - `TABULAR_TRAINING_PRESET = "demo"`: longer demonstration run for a suitable runtime.
# - `TABULAR_TRAINING_PRESET = "skip"`: use the teaching fallback for fast structure checks.
# - `RUN_GANBLR = True`: use GANBLR when available.

# %%
from pathlib import Path
import importlib.util
import subprocess
import sys
import warnings

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a managed local environment.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"
RUN_GANBLR = True
USE_TEACHING_FALLBACK_IF_GANBLR_UNAVAILABLE = True
RANDOM_STATE = 742
TABULAR_TRAINING_PRESET = "quick"  # Use "quick", "demo", or "skip".

BASE_PACKAGE_SPECS = [
    "numpy",
    "pandas",
    "scikit-learn",
    "matplotlib",
    "networkx",
]
GANBLR_PACKAGE_SPEC = "ganblr==0.1.3"
GANBLR_GITHUB_FALLBACK_SPEC = "git+https://github.com/tulip-lab/ganblr.git"


def install_packages(package_specs):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *package_specs])


def missing_imports(import_names):
    return [name for name in import_names if importlib.util.find_spec(name) is None]


base_imports = ["numpy", "pandas", "sklearn", "matplotlib", "networkx"]
missing_base = missing_imports(base_imports)
if missing_base:
    if INSTALL_MISSING_PACKAGES:
        install_packages(BASE_PACKAGE_SPECS)
    else:
        raise ModuleNotFoundError(
            "Missing required packages: "
            + ", ".join(missing_base)
            + ". Install them in the active environment, or set EXECUTION_MODE = 'online'."
        )

GANBLR_AVAILABLE = importlib.util.find_spec("ganblr") is not None
if RUN_GANBLR and not GANBLR_AVAILABLE and INSTALL_MISSING_PACKAGES:
    try:
        install_packages([GANBLR_PACKAGE_SPEC])
        GANBLR_AVAILABLE = importlib.util.find_spec("ganblr") is not None
    except Exception as exc:
        warnings.warn(f"Could not install {GANBLR_PACKAGE_SPEC}: {exc}")
        try:
            install_packages([GANBLR_GITHUB_FALLBACK_SPEC])
            GANBLR_AVAILABLE = importlib.util.find_spec("ganblr") is not None
        except Exception as fallback_exc:
            warnings.warn(f"Could not install GANBLR from GitHub fallback: {fallback_exc}")

if RUN_GANBLR and not GANBLR_AVAILABLE and not USE_TEACHING_FALLBACK_IF_GANBLR_UNAVAILABLE:
    raise ModuleNotFoundError(
        "GANBLR is not available. Use EXECUTION_MODE = 'online' to install it, or set "
        "USE_TEACHING_FALLBACK_IF_GANBLR_UNAVAILABLE = True for code-flow practice."
    )

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

if RUN_GANBLR and GANBLR_AVAILABLE:
    from ganblr import get_demo_data
    from ganblr.models import GANBLR
else:
    get_demo_data = None
    GANBLR = None

np.random.seed(RANDOM_STATE)
print("Setup complete.")
print("Python version:", sys.version.split()[0])
print("Current working directory:", Path.cwd())
print("GANBLR available:", GANBLR_AVAILABLE)

# %% [markdown]
# Load the tabular data. In the primary path, this uses GANBLR's built-in discrete Adult demo dataset. In fallback mode, it creates a small adult-like categorical dataset for code-flow practice only.

# %%
TABULAR_TRAINING_CONFIGS = {
    "quick": {"max_rows": 1200, "epochs": 1, "batch_size": 32, "synthetic_size": 600, "evaluation_models": ["lr", "rf"]},
    "demo": {"max_rows": 5000, "epochs": 5, "batch_size": 64, "synthetic_size": 2000, "evaluation_models": ["lr", "rf", "mlp"]},
    "skip": {"max_rows": 800, "epochs": 0, "batch_size": 32, "synthetic_size": 400, "evaluation_models": ["lr", "rf"]},
}

if TABULAR_TRAINING_PRESET not in TABULAR_TRAINING_CONFIGS:
    raise ValueError("TABULAR_TRAINING_PRESET must be 'quick', 'demo', or 'skip'.")

training_config = TABULAR_TRAINING_CONFIGS[TABULAR_TRAINING_PRESET]


def make_teaching_adult_like_data(n_rows=1200, random_state=RANDOM_STATE):
    rng = np.random.default_rng(random_state)
    education = rng.choice(["school", "certificate", "bachelors", "masters"], size=n_rows, p=[0.28, 0.24, 0.33, 0.15])
    hours_band = rng.choice(["part_time", "standard", "long_hours"], size=n_rows, p=[0.20, 0.58, 0.22])
    age_band = rng.choice(["young", "mid", "senior"], size=n_rows, p=[0.30, 0.48, 0.22])
    workclass = rng.choice(["private", "public", "self_employed"], size=n_rows, p=[0.68, 0.22, 0.10])
    occupation = rng.choice(["service", "technical", "professional", "admin"], size=n_rows, p=[0.24, 0.26, 0.32, 0.18])

    score = (
        np.isin(education, ["bachelors", "masters"]).astype(int)
        + (hours_band == "long_hours").astype(int)
        + np.isin(occupation, ["technical", "professional"]).astype(int)
        + (age_band == "mid").astype(int)
    )
    probability_high_income = np.clip(0.12 + 0.18 * score, 0.05, 0.90)
    income = np.where(rng.random(n_rows) < probability_high_income, ">50K", "<=50K")

    return pd.DataFrame({
        "age_band": age_band,
        "workclass": workclass,
        "education": education,
        "occupation": occupation,
        "hours_band": hours_band,
        "income": income,
    })


def load_tabular_generation_data():
    if RUN_GANBLR and GANBLR_AVAILABLE:
        df = get_demo_data("adult")
        source = "GANBLR built-in discrete Adult demo dataset"
    else:
        df = make_teaching_adult_like_data(n_rows=training_config["max_rows"])
        source = "teaching fallback synthetic adult-like dataset"

    df = df.sample(frac=1.0, random_state=RANDOM_STATE).reset_index(drop=True)
    if training_config["max_rows"] and len(df) > training_config["max_rows"]:
        df = df.iloc[: training_config["max_rows"]].copy()
    return df, source


df, data_source = load_tabular_generation_data()

print("Data source:", data_source)
print("Training preset:", TABULAR_TRAINING_PRESET)
print("Data shape:", df.shape)
df.head()

# %% [markdown]
# Inspect the column types and category counts. Tabular generators need to preserve both individual column distributions and relationships between columns.

# %%
summary = pd.DataFrame({
    "column": df.columns,
    "dtype": [str(dtype) for dtype in df.dtypes],
    "n_unique": [df[column].nunique() for column in df.columns],
    "example_values": [", ".join(map(str, df[column].dropna().unique()[:4])) for column in df.columns],
})
summary

# %% [markdown]
# <a id="3-background-concepts"></a>
#
# ### 3. Background Concepts
#
# Image-generation notebooks often use convolutional GANs where the generator maps random latent vectors into pixel tensors. Tabular data is different: rows usually combine categorical, ordinal, and numeric columns, and important patterns can be hidden in dependencies between fields rather than visible shape.
#
# For tabular synthetic data, useful checks include:
#
# - whether each generated column has plausible values;
# - whether relationships between columns are preserved;
# - whether a model trained on synthetic data works on real holdout data;
# - whether the generated data creates privacy or leakage concerns.

# %%
comparison = pd.DataFrame([
    {
        "data type": "image data",
        "typical structure": "height x width x channels tensor",
        "common generator input": "random latent vector",
        "quality checks": "visual inspection, image metrics, downstream tasks",
    },
    {
        "data type": "tabular data",
        "typical structure": "rows x mixed-type columns",
        "common generator input": "observed row structure, dependencies, or latent variables",
        "quality checks": "marginal distributions, feature dependencies, TSTR/TRTR evaluation",
    },
])
comparison

# %% [markdown]
# A Bayesian network is one way to represent dependencies between tabular variables. The small example below samples a student-outcome table from a simple dependency graph. This is not GANBLR; it is a compact dependency example before the GANBLR workflow.

# %%
def sample_student_network_with_pgmpy(sample_size=200, random_state=RANDOM_STATE):
    try:
        from pgmpy.factors.discrete import TabularCPD
        from pgmpy.sampling import BayesianModelSampling
        try:
            from pgmpy.models import DiscreteBayesianNetwork as NetworkClass
        except ImportError:
            from pgmpy.models import BayesianNetwork as NetworkClass
    except Exception as exc:
        warnings.warn(f"pgmpy is unavailable; using a direct categorical sampler. Original error: {exc}")
        return sample_student_network_direct(sample_size=sample_size, random_state=random_state)

    model = NetworkClass([("Difficulty", "Grade"), ("Interest", "Grade"), ("Grade", "Recommendation")])
    cpd_difficulty = TabularCPD("Difficulty", 2, [[0.65], [0.35]], state_names={"Difficulty": ["standard", "hard"]})
    cpd_interest = TabularCPD("Interest", 2, [[0.55], [0.45]], state_names={"Interest": ["low", "high"]})
    cpd_grade = TabularCPD(
        "Grade",
        3,
        values=[
            [0.45, 0.15, 0.20, 0.05],
            [0.40, 0.45, 0.50, 0.35],
            [0.15, 0.40, 0.30, 0.60],
        ],
        evidence=["Difficulty", "Interest"],
        evidence_card=[2, 2],
        state_names={
            "Grade": ["pass", "credit", "distinction"],
            "Difficulty": ["standard", "hard"],
            "Interest": ["low", "high"],
        },
    )
    cpd_recommendation = TabularCPD(
        "Recommendation",
        2,
        values=[[0.70, 0.35, 0.10], [0.30, 0.65, 0.90]],
        evidence=["Grade"],
        evidence_card=[3],
        state_names={"Recommendation": ["no", "yes"], "Grade": ["pass", "credit", "distinction"]},
    )
    model.add_cpds(cpd_difficulty, cpd_interest, cpd_grade, cpd_recommendation)
    model.check_model()
    sampler = BayesianModelSampling(model)
    try:
        samples = sampler.forward_sample(size=sample_size, seed=random_state, show_progress=False)
    except TypeError:
        np.random.seed(random_state)
        samples = sampler.forward_sample(size=sample_size, show_progress=False)
    return samples


def sample_student_network_direct(sample_size=200, random_state=RANDOM_STATE):
    rng = np.random.default_rng(random_state)
    difficulty = rng.choice(["standard", "hard"], p=[0.65, 0.35], size=sample_size)
    interest = rng.choice(["low", "high"], p=[0.55, 0.45], size=sample_size)
    grade = []
    for d, i in zip(difficulty, interest):
        if d == "hard" and i == "high":
            probs = [0.05, 0.35, 0.60]
        elif d == "standard" and i == "high":
            probs = [0.15, 0.45, 0.40]
        elif d == "hard" and i == "low":
            probs = [0.20, 0.50, 0.30]
        else:
            probs = [0.45, 0.40, 0.15]
        grade.append(rng.choice(["pass", "credit", "distinction"], p=probs))
    recommendation = [rng.choice(["no", "yes"], p=[0.70, 0.30]) if g == "pass" else rng.choice(["no", "yes"], p=[0.25, 0.75]) for g in grade]
    return pd.DataFrame({"Difficulty": difficulty, "Interest": interest, "Grade": grade, "Recommendation": recommendation})


student_samples = sample_student_network_with_pgmpy(sample_size=200)
student_samples.head()

# %%
graph = nx.DiGraph([("Difficulty", "Grade"), ("Interest", "Grade"), ("Grade", "Recommendation")])
pos = nx.spring_layout(graph, seed=RANDOM_STATE)
plt.figure(figsize=(6, 4))
nx.draw_networkx(graph, pos=pos, node_color="#8ecae6", node_size=1800, arrows=True)
plt.title("Small Bayesian network for tabular generation")
plt.axis("off")
plt.show()

student_samples.value_counts("Grade", normalize=True).rename("proportion").to_frame()

# %% [markdown]
# <a id="4-guided-example-generate-tabular-data"></a>
#
# ### 4. Guided Example: Generate Tabular Data
#
# GANBLR learns a tabular generator from observed rows and labels. The setup below uses the final column as the target label, creates a reproducible train-test split, and keeps the default sample size bounded for ordinary notebook execution.

# %%
class FrequencyTabularGenerator:
    """A simple independent-column sampler used only when GANBLR is unavailable."""

    def fit(self, x, y, random_state=RANDOM_STATE):
        self.random_state = random_state
        self.feature_columns = list(x.columns)
        self.target_name = y.name or "target"
        training_frame = pd.concat([x.reset_index(drop=True), y.reset_index(drop=True).rename(self.target_name)], axis=1)
        self.columns = list(training_frame.columns)
        self.distributions = {}
        for column in self.columns:
            counts = training_frame[column].astype(str).value_counts(normalize=True)
            self.distributions[column] = (counts.index.to_numpy(), counts.to_numpy())
        return self

    def sample(self, size, verbose=0):
        rng = np.random.default_rng(self.random_state)
        sampled = {}
        for column, (values, probabilities) in self.distributions.items():
            sampled[column] = rng.choice(values, size=size, p=probabilities)
        return pd.DataFrame(sampled, columns=self.columns).to_numpy()

    def evaluate(self, x_test, y_test, model="lr"):
        synthetic = pd.DataFrame(self.sample(len(x_test)), columns=[*self.feature_columns, self.target_name])
        return evaluate_classifier(
            synthetic[self.feature_columns],
            synthetic[self.target_name],
            x_test,
            y_test,
            model_name=model,
        )


def build_classifier(model_name, x_train_for_shape):
    if model_name == "lr":
        estimator = LogisticRegression(max_iter=500, random_state=RANDOM_STATE)
    elif model_name == "rf":
        estimator = RandomForestClassifier(n_estimators=80, random_state=RANDOM_STATE)
    elif model_name == "mlp":
        estimator = MLPClassifier(hidden_layer_sizes=(32,), max_iter=200, random_state=RANDOM_STATE)
    else:
        raise ValueError("model_name must be 'lr', 'rf', or 'mlp'.")

    try:
        encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
    except TypeError:
        encoder = OneHotEncoder(handle_unknown="ignore", sparse=False)

    feature_indexes = list(range(np.asarray(x_train_for_shape).shape[1]))
    return Pipeline([
        ("encode", ColumnTransformer([("categorical", encoder, feature_indexes)], remainder="drop")),
        ("model", estimator),
    ])


def evaluate_classifier(x_train, y_train, x_test, y_test, model_name="lr"):
    pipeline = build_classifier(model_name, x_train)
    pipeline.fit(np.asarray(x_train), np.asarray(y_train).ravel())
    predictions = pipeline.predict(np.asarray(x_test))
    return accuracy_score(np.asarray(y_test).ravel(), predictions)

# %%
target_column = df.columns[-1]
X = df.drop(columns=[target_column])
y = df[target_column]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.35,
    random_state=RANDOM_STATE,
    stratify=y if y.nunique() > 1 else None,
)

print("Target column:", target_column)
print("Training shape:", X_train.shape, y_train.shape)
print("Test shape:", X_test.shape, y_test.shape)
y_train.value_counts(normalize=True).rename("training_target_proportion").to_frame()

# %% [markdown]
# Fit the tabular generator. In the primary path this trains GANBLR. In the labelled fallback path this trains a simple independent-column sampler so later evaluation cells still run; do not treat fallback outputs as GANBLR results.

# %%
if RUN_GANBLR and GANBLR_AVAILABLE and training_config["epochs"] > 0:
    tabular_generator = GANBLR()
    tabular_generator.fit(
        X_train,
        y_train,
        k=0,
        epochs=training_config["epochs"],
        batch_size=training_config["batch_size"],
        verbose=1,
    )
    generator_label = "GANBLR"
elif RUN_GANBLR and GANBLR_AVAILABLE and training_config["epochs"] == 0:
    tabular_generator = FrequencyTabularGenerator().fit(X_train, y_train)
    generator_label = "frequency teaching fallback because TABULAR_TRAINING_PRESET='skip'"
else:
    tabular_generator = FrequencyTabularGenerator().fit(X_train, y_train)
    generator_label = "frequency teaching fallback because GANBLR is unavailable"

print("Generator used:", generator_label)

# %% [markdown]
# Sample synthetic rows from the fitted generator and inspect the first few generated records.

# %%
synthetic_array = tabular_generator.sample(training_config["synthetic_size"], verbose=0)
synthetic_df = pd.DataFrame(synthetic_array, columns=df.columns)

print("Synthetic data shape:", synthetic_df.shape)
synthetic_df.head(10)

# %% [markdown]
# <a id="5-practical-exercise-evaluate-synthetic-tabular-data"></a>
#
# ### 5. Practical Exercise: Evaluate Synthetic Tabular Data
#
# Start with a simple marginal distribution check. Here the target column is compared between the real and generated data.

# %%
def compare_marginal_distribution(real_frame, synthetic_frame, column):
    real = real_frame[column].astype(str).value_counts(normalize=True).rename("real")
    synthetic = synthetic_frame[column].astype(str).value_counts(normalize=True).rename("synthetic")
    comparison = pd.concat([real, synthetic], axis=1).fillna(0.0)
    comparison["absolute_difference"] = (comparison["real"] - comparison["synthetic"]).abs()
    return comparison.sort_values("absolute_difference", ascending=False)


column_to_compare = target_column
marginal_comparison = compare_marginal_distribution(df, synthetic_df, column_to_compare)
marginal_comparison

# %%
ax = marginal_comparison[["real", "synthetic"]].plot(kind="bar", figsize=(7, 4))
ax.set_title(f"Real vs synthetic distribution: {column_to_compare}")
ax.set_ylabel("Proportion")
ax.set_xlabel(column_to_compare)
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# TSTR means **train on synthetic, test on real**. TRTR means **train on real, test on real**. When the synthetic data preserves useful predictive signal, the TSTR score should be closer to the TRTR score. A small gap does not prove privacy or safety; it is only one utility check.

# %%
evaluation_records = []

synthetic_X = synthetic_df.drop(columns=[target_column])
synthetic_y = synthetic_df[target_column]

for model_name in training_config["evaluation_models"]:
    tstr_score = tabular_generator.evaluate(X_test, y_test, model=model_name)
    trtr_score = evaluate_classifier(X_train, y_train, X_test, y_test, model_name=model_name)
    evaluation_records.append({
        "model": model_name.upper(),
        "TSTR_train_synthetic_test_real": tstr_score,
        "TRTR_train_real_test_real": trtr_score,
        "absolute_gap": abs(trtr_score - tstr_score),
    })

evaluation_table = pd.DataFrame(evaluation_records)
evaluation_table

# %% [markdown]
# Try one controlled change and record the result. Keep the change small so you can explain what changed.

# %%
# TODO: choose one controlled change and rerun the relevant cells.
# Examples:
# - change TABULAR_TRAINING_PRESET from "quick" to "demo" in a suitable runtime;
# - compare a different column in compare_marginal_distribution;
# - add "mlp" to the evaluation model list for a longer run;
# - set RUN_GANBLR = False to compare the labelled teaching fallback with GANBLR.

experiment_notes = {
    "change_made": "Describe the one change you tested.",
    "expected_effect": "Write what you expected to happen.",
    "observed_effect": "Summarise what changed in distributions or TSTR/TRTR scores.",
    "runtime_notes": "Record package, install, or training-time issues.",
}

experiment_notes

# %% [markdown]
# <a id="6-student-tasks"></a>
#
# ### 6. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Summarise the column types and category counts in the tabular dataset.</td>
# <td>Tabular generators must handle mixed structure and discrete values.</td>
# <td>The summary table plus a short written observation.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Explain the difference between the Bayesian-network sampler and the GANBLR workflow.</td>
# <td>Both involve dependencies, but they are not the same modelling approach.</td>
# <td>A two- or three-sentence comparison.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Generate synthetic rows and compare at least one real and synthetic marginal distribution.</td>
# <td>Distribution checks are a first utility sanity check.</td>
# <td>A comparison table or plot and a short interpretation.</td>
# </tr>
# <tr>
# <td align="left">Task 4</td>
# <td>Compare TSTR and TRTR results for the default evaluation models.</td>
# <td>Downstream utility checks help reveal whether synthetic data preserves useful predictive signal.</td>
# <td>The evaluation table and a cautious interpretation of the score gap.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# <a id="7-reflection-and-references"></a>
#
# ### 7. Reflection and References
#
# Run the quick checks first, then answer the reflection questions.

# %%
assert not df.empty
assert target_column in df.columns
assert X_train.shape[0] > 0 and X_test.shape[0] > 0
assert synthetic_df.shape[0] == training_config["synthetic_size"]
assert list(synthetic_df.columns) == list(df.columns)
assert set(evaluation_table.columns) == {
    "model",
    "TSTR_train_synthetic_test_real",
    "TRTR_train_real_test_real",
    "absolute_gap",
}
score_values = evaluation_table[["TSTR_train_synthetic_test_real", "TRTR_train_real_test_real"]].to_numpy(dtype=float)
assert np.isfinite(score_values).all()

print("Notebook checks passed.")

# %% [markdown]
# Reflection questions:
#
# 1. Why is visual inspection less useful for tabular synthetic data than for image generation?
# 2. What does a small TSTR/TRTR gap suggest, and what does it not prove?
# 3. Which column relationship would you inspect next to evaluate synthetic data quality?
# 4. What additional checks would be needed before synthetic tabular data could be shared outside a teaching demonstration?
#
# Further readings:
#
# - GANBLR package documentation: https://ganblr-docs.readthedocs.io/en/latest/
# - GANBLR package repository: https://github.com/tulip-lab/ganblr
# - Zhang, Y., Zaidi, N. A., Zhou, J., and Li, G. (2021). GANBLR: A Tabular Data Generation Model. IEEE ICDM. https://doi.org/10.1109/ICDM51629.2021.00103
# - UCI Adult dataset documentation: https://archive.ics.uci.edu/dataset/2/adult
# - scikit-learn model evaluation documentation: https://scikit-learn.org/stable/modules/model_evaluation.html
