# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 06: Advanced)**
#
# **Session 6G: Image-to-Text Generation and Caption Analysis**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, privacy-aware analytics, generative modelling, and applied machine learning.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find an issue in this notebook, please raise it through the SIT742 repository issue tracker.
#
# Prepared by the **SIT742 Teaching Team**.
#
# ---
#
# ## Notebook Metadata
#
# | Item | Detail |
# | --- | --- |
# | Unit module | Module 06, Advanced |
# | Session | 6G, Image-to-Text Generation and Caption Analysis |
# | Expected practical time | Approximately 48 minutes |
# | Environment | Google Colab or local Jupyter with Python, Pillow, pandas, scikit-learn, Matplotlib, and optional PyTorch/Transformers/WordCloud |
# | Main ideas | Image captioning, transformer encoder-decoder models, generated text analysis, topic modelling, responsible interpretation |
# | Data | Public `deakintweets.zip` image archive from the SIT742 repository |
#
# ## Table of Contents
#
# 1. Overview and Learning Goals
# 2. Setup and Required Packages
# 3. Background Concepts
# 4. Guided Example: Generate Image Captions
# 5. Practical Exercise: Analyse Generated Captions
# 6. Student Tasks
# 7. Reflection and References

# %% [markdown]
# ## 1. Overview and Learning Goals
#
# Image-to-text systems generate text from visual input. In this notebook, you will use a bounded image-captioning workflow to create captions for a small public image archive, then treat the generated captions as text data for word counts and topic modelling.
#
# By the end of this notebook, you should be able to:
#
# 1. describe the difference between image captioning, OCR, and text-to-image generation;
# 2. load a public image archive in both online and local notebook environments;
# 3. use a Hugging Face image-captioning model when the runtime supports it;
# 4. continue the text-analysis workflow with a clearly labelled teaching fallback if model download is unavailable;
# 5. summarise generated captions with word counts, LDA topics, and topic-to-image displays;
# 6. discuss quality, compute, and ethical limitations of generated image captions.
#
# This notebook is designed for practical learning. The generated captions are model outputs that need human interpretation; they should not be treated as ground-truth labels.

# %% [markdown]
# ## 2. Setup and Required Packages
#
# Use `EXECUTION_MODE = "online"` in Google Colab or another online notebook service. This mode downloads the public image archive from GitHub and installs missing packages when needed.
#
# Use `EXECUTION_MODE = "local"` when running from a cloned SIT742 repository. In local mode, the notebook first looks for `../data/deakintweets.zip`, which is the relative path from this notebook's folder.
#
# The Hugging Face model is optional for code-flow practice. If the model or its dependencies are unavailable, the notebook can use a labelled teaching fallback so the later text-analysis cells still run. Do not present fallback captions as model-generated captions.

# %%
from pathlib import Path
from urllib.request import urlretrieve
from zipfile import ZipFile
import importlib.util
import subprocess
import sys
import warnings

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a cloned SIT742 repository.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"
RUN_IMAGE_CAPTION_MODEL = True
USE_TEACHING_FALLBACK_IF_MODEL_UNAVAILABLE = True
RANDOM_STATE = 742
MAX_IMAGES = 8
CAPTION_BATCH_SIZE = 2
MODEL_NAME = "nlpconnect/vit-gpt2-image-captioning"

BASE_PACKAGE_SPECS = [
    "numpy",
    "pandas",
    "scikit-learn",
    "matplotlib",
    "pillow",
]
CAPTION_PACKAGE_SPECS = [
    "torch",
    "transformers>=4.40,<6",
]
OPTIONAL_PACKAGE_SPECS = ["wordcloud"]


def install_packages(package_specs):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *package_specs])


def missing_imports(import_names):
    return [name for name in import_names if importlib.util.find_spec(name) is None]


base_imports = ["numpy", "pandas", "sklearn", "matplotlib", "PIL"]
missing_base = missing_imports(base_imports)
if missing_base:
    if INSTALL_MISSING_PACKAGES:
        install_packages(BASE_PACKAGE_SPECS)
    else:
        raise ModuleNotFoundError(
            "Missing required packages: "
            + ", ".join(missing_base)
            + ". Install them in the active environment, or set EXECUTION_MODE = 'online'."
        )

CAPTION_PACKAGES_AVAILABLE = not missing_imports(["torch", "transformers"])
if RUN_IMAGE_CAPTION_MODEL and not CAPTION_PACKAGES_AVAILABLE and INSTALL_MISSING_PACKAGES:
    try:
        install_packages(CAPTION_PACKAGE_SPECS)
        CAPTION_PACKAGES_AVAILABLE = not missing_imports(["torch", "transformers"])
    except Exception as exc:
        warnings.warn(f"Could not install image-captioning packages: {exc}")
        CAPTION_PACKAGES_AVAILABLE = False

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageStat
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

np.random.seed(RANDOM_STATE)
print("Setup complete.")
print("Python version:", sys.version.split()[0])
print("Caption packages available:", CAPTION_PACKAGES_AVAILABLE)

# %% [markdown]
# ## 3. Background Concepts
#
# ### Image Captioning, OCR, and Text-to-Image
#
# | Task | Input | Output | Example use |
# | --- | --- | --- | --- |
# | Image captioning | Image | Natural-language description | Describe the main scene or objects in an image |
# | OCR | Image containing text | Extracted text | Read a scanned page or sign |
# | Text-to-image generation | Text prompt | New image | Generate a synthetic illustration from a description |
#
# This notebook focuses on image captioning. A common architecture uses a vision encoder to represent the image and a language decoder to generate words. The original notebook used the public Hugging Face model `nlpconnect/vit-gpt2-image-captioning`, which combines a vision transformer encoder with a GPT-style decoder.
#
# Generated captions are useful teaching data because they connect image understanding, language generation, and text mining. They also raise quality and ethics questions: captions can be vague, biased, wrong, or overconfident.

# %% [markdown]
# ## 4. Guided Example: Generate Image Captions
#
# First load the public image archive. The online path downloads the archive from GitHub into the notebook runtime. The local path uses the repository copy when it is available.

# %%
DATA_URL = "https://raw.githubusercontent.com/tulip-lab/sit742/develop/Jupyter/data/deakintweets.zip"
WORK_DIR = Path("data") / "m06g-image-text"
ARCHIVE_PATH = WORK_DIR / "deakintweets.zip"
IMAGE_DIR = WORK_DIR / "deakintweets"
LOCAL_ARCHIVE_CANDIDATES = [
    Path("../data/deakintweets.zip"),
    Path("Jupyter/data/deakintweets.zip"),
    Path("SIT742/Jupyter/data/deakintweets.zip"),
]

WORK_DIR.mkdir(parents=True, exist_ok=True)
IMAGE_DIR.mkdir(parents=True, exist_ok=True)


def find_local_archive():
    for candidate in LOCAL_ARCHIVE_CANDIDATES:
        if candidate.exists():
            return candidate
    return None


if EXECUTION_MODE == "local" and find_local_archive() is not None:
    source_archive = find_local_archive()
    print("Using local archive:", source_archive)
else:
    print("Downloading public image archive from GitHub...")
    urlretrieve(DATA_URL, ARCHIVE_PATH)
    source_archive = ARCHIVE_PATH

with ZipFile(source_archive) as archive:
    archive.extractall(IMAGE_DIR)

image_paths = sorted(
    path for path in IMAGE_DIR.iterdir()
    if path.suffix.lower() in {".jpg", ".jpeg", ".png"}
)
selected_image_paths = image_paths[:MAX_IMAGES]

print(f"Total images available: {len(image_paths)}")
print(f"Images selected for this run: {len(selected_image_paths)}")
selected_image_paths[:3]

# %%
def show_image_grid(paths, captions=None, columns=4):
    captions = captions or [path.name for path in paths]
    rows = int(np.ceil(len(paths) / columns))
    fig, axes = plt.subplots(rows, columns, figsize=(4 * columns, 3.2 * rows))
    axes = np.array(axes).reshape(-1)
    for axis, path, caption in zip(axes, paths, captions):
        image = Image.open(path).convert("RGB")
        axis.imshow(image)
        axis.set_title(caption[:70], fontsize=9)
        axis.axis("off")
    for axis in axes[len(paths):]:
        axis.axis("off")
    plt.tight_layout()
    plt.show()


show_image_grid(selected_image_paths, columns=4)

# %% [markdown]
# The next cell loads the caption model when the runtime supports it. The model download can take time and may require internet access. If it fails, the notebook uses a clearly labelled fallback based on simple image metadata so the text-analysis workflow can still be practised.

# %%
def load_caption_components():
    if not (RUN_IMAGE_CAPTION_MODEL and CAPTION_PACKAGES_AVAILABLE):
        return None
    try:
        import torch
        from transformers import AutoTokenizer, ViTImageProcessor, VisionEncoderDecoderModel

        model = VisionEncoderDecoderModel.from_pretrained(MODEL_NAME)
        processor = ViTImageProcessor.from_pretrained(MODEL_NAME)
        tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model.to(device)
        model.eval()
        return {"model": model, "processor": processor, "tokenizer": tokenizer, "device": device, "torch": torch}
    except Exception as exc:
        warnings.warn(f"Could not load {MODEL_NAME}; using the teaching fallback if enabled. Original error: {exc}")
        return None


def fallback_caption(image_path):
    image = Image.open(image_path).convert("RGB")
    width, height = image.size
    stat = ImageStat.Stat(image.resize((1, 1)))
    red, green, blue = stat.mean
    brightness = (red + green + blue) / 3
    orientation = "landscape" if width > height else "portrait" if height > width else "square"
    brightness_label = "bright" if brightness >= 170 else "dark" if brightness <= 85 else "moderately lit"
    dominant_channel = max((red, "red"), (green, "green"), (blue, "blue"))[1]
    return (
        f"teaching fallback caption: a {orientation} {brightness_label} image "
        f"with a stronger {dominant_channel} colour channel"
    )


def generate_model_captions(paths, components):
    model = components["model"]
    processor = components["processor"]
    tokenizer = components["tokenizer"]
    device = components["device"]
    torch = components["torch"]
    captions = []
    generation_config = {"max_length": 32, "num_beams": 2}
    for start in range(0, len(paths), CAPTION_BATCH_SIZE):
        batch_paths = paths[start : start + CAPTION_BATCH_SIZE]
        images = [Image.open(path).convert("RGB") for path in batch_paths]
        pixel_values = processor(images=images, return_tensors="pt").pixel_values.to(device)
        with torch.no_grad():
            output_ids = model.generate(pixel_values, **generation_config)
        captions.extend(tokenizer.batch_decode(output_ids, skip_special_tokens=True))
    return [caption.strip() for caption in captions]


caption_components = load_caption_components()
if caption_components is None:
    if not USE_TEACHING_FALLBACK_IF_MODEL_UNAVAILABLE:
        raise RuntimeError("Caption model is unavailable and the teaching fallback is disabled.")
    caption_source = "teaching fallback"
    generated_captions = [fallback_caption(path) for path in selected_image_paths]
else:
    caption_source = f"Hugging Face model: {MODEL_NAME}"
    generated_captions = generate_model_captions(selected_image_paths, caption_components)

caption_df = pd.DataFrame({
    "image_file": [path.name for path in selected_image_paths],
    "caption": generated_captions,
    "caption_source": caption_source,
})

print("Caption source:", caption_source)
caption_df

# %%
show_image_grid(
    selected_image_paths,
    captions=[f"{row.image_file}\n{row.caption}" for row in caption_df.itertuples()],
    columns=2,
)

# %% [markdown]
# ## 5. Practical Exercise: Analyse Generated Captions
#
# Now treat the generated captions as text data. The aim is not to prove the captions are correct. The aim is to practise a simple workflow: vectorise the generated text, inspect frequent words, fit a small topic model, and map topic assignments back to images.

# %%
count_vectorizer = CountVectorizer(
    stop_words="english",
    token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z]+\b",
)
count_matrix = count_vectorizer.fit_transform(caption_df["caption"])
terms = count_vectorizer.get_feature_names_out()
term_counts = np.asarray(count_matrix.sum(axis=0)).ravel()

term_frequency = (
    pd.DataFrame({"term": terms, "count": term_counts})
    .sort_values("count", ascending=False)
    .reset_index(drop=True)
)
term_frequency.head(20)

# %%
top_terms = term_frequency.head(20)
ax = top_terms.plot.bar(x="term", y="count", figsize=(10, 4), legend=False)
ax.set_title("Most frequent terms in generated captions")
ax.set_xlabel("Term")
ax.set_ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
NUMBER_TOPICS = min(3, count_matrix.shape[0], count_matrix.shape[1])
if NUMBER_TOPICS < 1:
    raise ValueError("Not enough caption terms for topic modelling.")

lda_model = LatentDirichletAllocation(
    n_components=NUMBER_TOPICS,
    random_state=RANDOM_STATE,
    learning_method="batch",
)
lda_model.fit(count_matrix)

def top_words_for_topic(topic_index, n_words=6):
    weights = lda_model.components_[topic_index]
    top_indexes = weights.argsort()[::-1][:n_words]
    return ", ".join(terms[index] for index in top_indexes)


topic_summary = pd.DataFrame({
    "topic": [f"Topic {index + 1}" for index in range(NUMBER_TOPICS)],
    "top_words": [top_words_for_topic(index) for index in range(NUMBER_TOPICS)],
})
topic_summary

# %%
topic_distribution = lda_model.transform(count_matrix)
caption_df["dominant_topic"] = topic_distribution.argmax(axis=1) + 1
caption_df["dominant_topic_probability"] = topic_distribution.max(axis=1).round(3)
caption_df[["image_file", "caption", "dominant_topic", "dominant_topic_probability"]]

# %%
try:
    if importlib.util.find_spec("wordcloud") is None and INSTALL_MISSING_PACKAGES:
        install_packages(OPTIONAL_PACKAGE_SPECS)
    from wordcloud import WordCloud
    WORDCLOUD_AVAILABLE = True
except Exception as exc:
    warnings.warn(f"WordCloud is unavailable; using bar charts instead. Original error: {exc}")
    WORDCLOUD_AVAILABLE = False

columns = min(3, NUMBER_TOPICS)
rows = int(np.ceil(NUMBER_TOPICS / columns))
fig, axes = plt.subplots(rows, columns, figsize=(5 * columns, 3.5 * rows))
axes = np.array(axes).reshape(-1)

for topic_index in range(NUMBER_TOPICS):
    weights = lda_model.components_[topic_index]
    top_indexes = weights.argsort()[::-1][:10]
    frequencies = {terms[index]: float(weights[index]) for index in top_indexes}
    axis = axes[topic_index]
    if WORDCLOUD_AVAILABLE:
        cloud = WordCloud(background_color="white", random_state=RANDOM_STATE).generate_from_frequencies(frequencies)
        axis.imshow(cloud, interpolation="bilinear")
        axis.axis("off")
    else:
        pd.Series(frequencies).sort_values().plot.barh(ax=axis)
    axis.set_title(f"Topic {topic_index + 1}")

for axis in axes[NUMBER_TOPICS:]:
    axis.axis("off")
plt.tight_layout()
plt.show()

# %%
for topic_number, group in caption_df.groupby("dominant_topic"):
    print(f"Topic {topic_number}: {len(group)} image(s)")
    paths = [IMAGE_DIR / file_name for file_name in group["image_file"]]
    labels = [caption[:85] for caption in group["caption"]]
    show_image_grid(paths, captions=labels, columns=min(3, len(paths)))

# %% [markdown]
# ## 6. Student Tasks
#
# Complete the following tasks in your own notebook run.
#
# 1. Change `MAX_IMAGES` to a different value between 4 and 12. Record how this changes the term-frequency table and topic model.
# 2. Change `num_beams` inside `generate_model_captions` from `2` to another value if the Hugging Face model is available. Compare one caption before and after the change.
# 3. Add one extra stop word to the `CountVectorizer` configuration and explain why you removed it.
# 4. Choose one image-topic assignment and write two sentences about whether the dominant topic seems meaningful.
# 5. Write a short note on one ethical or quality risk when generated captions are used as labels for downstream analysis.
#
# Use the following dictionary to record your observations.

# %%
experiment_notes = {
    "caption_source_used": caption_source,
    "max_images": MAX_IMAGES,
    "one_caption_quality_observation": "",
    "one_topic_modelling_observation": "",
    "one_ethical_or_quality_risk": "",
}
experiment_notes

# %% [markdown]
# Run the final checks before you finish. Passing checks only confirms that the notebook objects have the expected shape; it does not confirm that the captions are semantically correct.

# %%
assert len(image_paths) >= len(selected_image_paths) > 0
assert len(caption_df) == len(selected_image_paths)
assert caption_df["caption"].str.len().gt(0).all()
assert count_matrix.shape[0] == len(caption_df)
assert count_matrix.shape[1] == len(terms)
assert NUMBER_TOPICS >= 1
assert len(topic_summary) == NUMBER_TOPICS
assert caption_df["dominant_topic"].between(1, NUMBER_TOPICS).all()
assert "ethical" in " ".join(experiment_notes.keys())

print("Notebook checks passed.")

# %% [markdown]
# ## 7. Reflection and References
#
# Reflect on the following questions:
#
# 1. Which generated caption seemed most useful, and why?
# 2. Which generated caption seemed least reliable, and what might explain the error?
# 3. How did the topic model simplify or distort the caption set?
# 4. What extra validation would be needed before generated captions could be used in a real data product?
#
# References and further reading:
#
# - Hugging Face Transformers documentation: <https://huggingface.co/docs/transformers>
# - Hugging Face image captioning task guide: <https://huggingface.co/tasks/image-to-text>
# - Model card: `nlpconnect/vit-gpt2-image-captioning`, <https://huggingface.co/nlpconnect/vit-gpt2-image-captioning>
# - scikit-learn `LatentDirichletAllocation`: <https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html>
# - scikit-learn text feature extraction: <https://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction>
