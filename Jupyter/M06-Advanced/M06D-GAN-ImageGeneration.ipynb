# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 06: Advanced)**
#
# **Session 6D: Generative Adversarial Networks for Image Generation**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, privacy-aware analytics, generative modelling, and applied machine learning.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for Module 06.</td>
# </tr>
# <tr>
# <td align="left">Estimated duration</td>
# <td>Approximately 48 minutes, based on 240 minutes of M06 practical/self-learning work across five notebooks.</td>
# </tr>
# <tr>
# <td align="left">Environment</td>
# <td>Google Colab or local Jupyter with TensorFlow, NumPy, pandas, and Matplotlib.</td>
# </tr>
# <tr>
# <td align="left">Main output</td>
# <td>A small GAN workflow that loads image data, builds generator and discriminator networks, runs bounded training, and inspects generated images.</td>
# </tr>
# <tr>
# <td align="left">Related assessment</td>
# <td>General practical skill development; not directly assessed.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---
#
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Required Packages](#2-setup-and-required-packages)
# - [3. Background Concepts](#3-background-concepts)
# - [4. Guided Example: Build the GAN Components](#4-guided-example-build-the-gan-components)
# - [5. Practical Exercise: Train and Inspect Generated Images](#5-practical-exercise-train-and-inspect-generated-images)
# - [6. Student Tasks](#6-student-tasks)
# - [7. Reflection and References](#7-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# Generative adversarial networks (GANs) train two neural networks together. A generator creates synthetic examples from random latent points, while a discriminator tries to distinguish generated examples from real examples. The generator improves by learning how to fool the discriminator.
#
# In this practical you will build a compact convolutional GAN for 28 by 28 grayscale images. The default run is intentionally bounded so that students can inspect the workflow in an ordinary notebook runtime. A longer GPU demonstration path is available by changing one configuration value.
#
# By the end of this practical, you should be able to:
#
# 1. explain the roles of the generator, discriminator, and latent space in a GAN;
# 2. load MNIST or Fashion-MNIST image data through Keras dataset loaders;
# 3. define a discriminator, generator, and combined GAN model in TensorFlow/Keras;
# 4. run a bounded GAN training loop and interpret the loss and discriminator-accuracy signals;
# 5. generate and inspect synthetic images without adding generated model or plot artifacts to repository history.

# %% [markdown]
# <a id="2-setup-and-required-packages"></a>
#
# ### 2. Setup and Required Packages
#
# This notebook uses TensorFlow/Keras built-in dataset loaders. The first run may download MNIST or Fashion-MNIST into the notebook runtime cache. No SIT742 repository data file is required.
#
# #### Option A: Google Colab / online execution
#
# Keep `EXECUTION_MODE = "online"`. The setup cell installs missing packages into the temporary runtime if needed. For the longer demonstration path, use a GPU runtime and set `TRAINING_PRESET = "gpu_demo"`.
#
# #### Option B: Local repository execution
#
# Use `EXECUTION_MODE = "local"` only when your local Python environment already has TensorFlow and the other required packages installed. Local mode raises a clear error instead of changing your environment automatically.
#
# Runtime controls:
#
# - `TRAINING_PRESET = "quick"`: small default run for code-flow practice.
# - `TRAINING_PRESET = "gpu_demo"`: longer run for a GPU runtime.
# - `TRAINING_PRESET = "skip"`: build the models and inspect untrained generated images.
# - `SAVE_ARTIFACTS = False`: keep generated models and plots out of the repository by default.

# %%
from pathlib import Path
import importlib.util
import subprocess
import sys
import warnings

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for a managed local environment.
INSTALL_MISSING_PACKAGES = EXECUTION_MODE == "online"
RANDOM_STATE = 742
DATASET_NAME = "mnist"  # Use "mnist" or "fashion_mnist".
TRAINING_PRESET = "quick"  # Use "quick", "gpu_demo", or "skip".
SAVE_ARTIFACTS = False
ARTIFACT_DIR = Path("generated-artifacts/m06d-gan")

PACKAGE_SPECS = [
    "tensorflow",
    "matplotlib",
    "numpy",
    "pandas",
]


def ensure_packages_available():
    import_map = {
        "tensorflow": "tensorflow",
        "matplotlib": "matplotlib",
        "numpy": "numpy",
        "pandas": "pandas",
    }
    missing = [
        pip_name
        for import_name, pip_name in import_map.items()
        if importlib.util.find_spec(import_name) is None
    ]
    if not missing:
        return
    if INSTALL_MISSING_PACKAGES:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", *missing])
        return
    raise ModuleNotFoundError(
        "Missing required packages: "
        + ", ".join(missing)
        + ". Install them in the active environment, or set EXECUTION_MODE = 'online' to install them in an online notebook runtime."
    )


ensure_packages_available()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.datasets import fashion_mnist, mnist
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, Dense, Dropout, Flatten, Input, LeakyReLU, Reshape
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

print("Setup complete.")
print("Python version:", sys.version.split()[0])
print("TensorFlow version:", tf.__version__)
print("Current working directory:", Path.cwd())
print("GPU devices:", tf.config.list_physical_devices("GPU"))

# %% [markdown]
# Load the working image tensor. The default `quick` preset samples a small subset so that the training loop stays responsive. You may switch `DATASET_NAME` to `"fashion_mnist"` if you want to repeat the same GAN workflow on clothing images.

# %%
TRAINING_CONFIGS = {
    "quick": {
        "n_epochs": 1,
        "n_batch": 128,
        "max_examples": 2048,
        "eval_interval": 1,
        "n_eval_samples": 64,
    },
    "gpu_demo": {
        "n_epochs": 10,
        "n_batch": 256,
        "max_examples": 20000,
        "eval_interval": 5,
        "n_eval_samples": 100,
    },
    "skip": {
        "n_epochs": 0,
        "n_batch": 128,
        "max_examples": 1024,
        "eval_interval": 1,
        "n_eval_samples": 25,
    },
}

if TRAINING_PRESET not in TRAINING_CONFIGS:
    raise ValueError("TRAINING_PRESET must be 'quick', 'gpu_demo', or 'skip'.")

training_config = TRAINING_CONFIGS[TRAINING_PRESET]


def load_real_samples(dataset_name=DATASET_NAME, max_examples=None, random_state=RANDOM_STATE):
    if dataset_name == "mnist":
        (train_images, _), (_, _) = mnist.load_data()
        dataset_label = "MNIST handwritten digits"
    elif dataset_name == "fashion_mnist":
        (train_images, _), (_, _) = fashion_mnist.load_data()
        dataset_label = "Fashion-MNIST clothing images"
    else:
        raise ValueError("DATASET_NAME must be 'mnist' or 'fashion_mnist'.")

    rng = np.random.default_rng(random_state)
    if max_examples is not None and max_examples < train_images.shape[0]:
        selected = rng.choice(train_images.shape[0], size=max_examples, replace=False)
        train_images = train_images[selected]

    images = np.expand_dims(train_images, axis=-1).astype("float32")
    images = images / 255.0
    return images, dataset_label


working_dataset, dataset_label = load_real_samples(max_examples=training_config["max_examples"])

print("Dataset:", dataset_label)
print("Training preset:", TRAINING_PRESET)
print("Working image tensor:", working_dataset.shape)
print("Pixel range:", float(working_dataset.min()), "to", float(working_dataset.max()))

# %% [markdown]
# Inspect a small grid of real images before building the GAN. This gives you a baseline for judging whether generated examples are starting to resemble the training distribution.

# %%
def show_image_grid(examples, n=5, title=None, cmap="gray"):
    examples = np.asarray(examples)
    if examples.ndim == 4 and examples.shape[-1] == 1:
        examples = examples[:, :, :, 0]
    fig, axes = plt.subplots(n, n, figsize=(n * 1.3, n * 1.3))
    for index, ax in enumerate(axes.flat):
        ax.axis("off")
        if index < len(examples):
            ax.imshow(examples[index], cmap=cmap, vmin=0.0, vmax=1.0)
    if title:
        fig.suptitle(title)
    fig.tight_layout()
    plt.show()
    return fig


sample_indices = np.random.default_rng(RANDOM_STATE).choice(working_dataset.shape[0], size=25, replace=False)
show_image_grid(working_dataset[sample_indices], n=5, title=f"Sample real images: {dataset_label}")

# %% [markdown]
# <a id="3-background-concepts"></a>
#
# ### 3. Background Concepts
#
# A GAN is a two-player training process:
#
# | Component | Role | In this notebook |
# | --- | --- | --- |
# | Latent space | Random input vectors sampled from a simple distribution | 100-dimensional normal vectors |
# | Generator | Maps latent vectors to synthetic images | Dense projection followed by transpose convolutions |
# | Discriminator | Classifies images as real or generated | Convolutional binary classifier |
# | Training loop | Alternates discriminator and generator updates | Real/fake batches for the discriminator; inverted labels for the generator |
#
# The standard GAN objective can be written as:
#
# $$\min_G \max_D V(D, G) = \mathbb{E}_{x \sim p_{data}}[\log D(x)] + \mathbb{E}_{z \sim p_z}[\log(1 - D(G(z)))]$$
#
# In practice, early generated images may look noisy. That is expected in a bounded teaching run. The goal here is to understand the workflow and diagnostics, not to produce publication-quality images.

# %% [markdown]
# <a id="4-guided-example-build-the-gan-components"></a>
#
# ### 4. Guided Example: Build the GAN Components
#
# The discriminator is a compact convolutional classifier. It receives a 28 by 28 grayscale image and predicts whether that image is real (`1`) or generated (`0`).

# %%
def define_discriminator(in_shape=(28, 28, 1)):
    model = Sequential(name="discriminator")
    model.add(Input(shape=in_shape))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding="same"))
    model.add(LeakyReLU(negative_slope=0.2))
    model.add(Dropout(0.4))
    model.add(Conv2D(64, (3, 3), strides=(2, 2), padding="same"))
    model.add(LeakyReLU(negative_slope=0.2))
    model.add(Dropout(0.4))
    model.add(Flatten())
    model.add(Dense(1, activation="sigmoid"))
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
    return model

# %% [markdown]
# The generator receives a point from the latent space and upsamples it into a 28 by 28 grayscale image. This preserves the original notebook's core idea: start from random noise and learn an image-producing network.

# %%
def define_generator(latent_dim):
    model = Sequential(name="generator")
    model.add(Input(shape=(latent_dim,)))
    n_nodes = 128 * 7 * 7
    model.add(Dense(n_nodes))
    model.add(LeakyReLU(negative_slope=0.2))
    model.add(Reshape((7, 7, 128)))
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"))
    model.add(LeakyReLU(negative_slope=0.2))
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"))
    model.add(LeakyReLU(negative_slope=0.2))
    model.add(Conv2D(1, (7, 7), activation="sigmoid", padding="same"))
    return model


def define_gan(generator_model, discriminator_model):
    discriminator_model.trainable = False
    model = Sequential(name="gan")
    model.add(generator_model)
    model.add(discriminator_model)
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss="binary_crossentropy", optimizer=opt)
    return model

# %% [markdown]
# The helper functions below sample real images, sample latent points, and ask the generator to create fake images. These are used inside the manual GAN training loop.

# %%
def generate_real_samples(dataset, n_samples):
    indices = np.random.randint(0, dataset.shape[0], n_samples)
    images = dataset[indices]
    labels = np.ones((n_samples, 1))
    return images, labels


def generate_latent_points(latent_dim, n_samples, random_state=None):
    rng = np.random.default_rng(random_state)
    latent_points = rng.standard_normal(latent_dim * n_samples)
    return latent_points.reshape(n_samples, latent_dim)


def generate_fake_samples(generator_model, latent_dim, n_samples):
    latent_points = generate_latent_points(latent_dim, n_samples)
    images = generator_model.predict(latent_points, verbose=0)
    labels = np.zeros((n_samples, 1))
    return images, labels

# %% [markdown]
# The training helper alternates two updates:
#
# 1. train the discriminator on a mixed batch of real and generated images;
# 2. train the generator through the combined GAN model using labels that encourage the discriminator to classify generated images as real.
#
# The helper evaluates the discriminator and displays generated images at a controlled interval. Model files are saved only when `SAVE_ARTIFACTS = True`.

# %%
def scalar_metric(value):
    if isinstance(value, (list, tuple)):
        return float(value[0])
    array = np.asarray(value)
    return float(array.reshape(-1)[0])


def summarise_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=64):
    real_images, real_labels = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(real_images, real_labels, verbose=0)
    fake_images, fake_labels = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(fake_images, fake_labels, verbose=0)

    print(f"Epoch {epoch + 1}: discriminator accuracy on real={acc_real:.3f}, fake={acc_fake:.3f}")
    show_image_grid(fake_images[:25], n=5, title=f"Generated images after epoch {epoch + 1}")

    model_path = None
    if SAVE_ARTIFACTS:
        ARTIFACT_DIR.mkdir(parents=True, exist_ok=True)
        model_path = ARTIFACT_DIR / f"generator_epoch_{epoch + 1:03d}.keras"
        generator_model.save(model_path)
        print("Saved generator model to", model_path)

    return {
        "epoch": epoch + 1,
        "accuracy_real": float(acc_real),
        "accuracy_fake": float(acc_fake),
        "model_path": str(model_path) if model_path else None,
    }


def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, n_epochs=1, n_batch=128, eval_interval=1, n_eval_samples=64):
    if n_epochs <= 0:
        print("TRAINING_PRESET is 'skip'; model weights remain randomly initialised.")
        return pd.DataFrame()

    batches_per_epoch = max(1, dataset.shape[0] // n_batch)
    half_batch = n_batch // 2
    history = []

    for epoch in range(n_epochs):
        batch_d_losses = []
        batch_g_losses = []
        for _ in range(batches_per_epoch):
            real_images, real_labels = generate_real_samples(dataset, half_batch)
            fake_images, fake_labels = generate_fake_samples(generator_model, latent_dim, half_batch)
            discriminator_images = np.vstack((real_images, fake_images))
            discriminator_labels = np.vstack((real_labels, fake_labels))

            discriminator_loss = discriminator_model.train_on_batch(discriminator_images, discriminator_labels)
            gan_latent_points = generate_latent_points(latent_dim, n_batch)
            gan_labels = np.ones((n_batch, 1))
            generator_loss = gan_model.train_on_batch(gan_latent_points, gan_labels)

            batch_d_losses.append(scalar_metric(discriminator_loss))
            batch_g_losses.append(scalar_metric(generator_loss))

        epoch_record = {
            "epoch": epoch + 1,
            "d_loss": float(np.mean(batch_d_losses)),
            "g_loss": float(np.mean(batch_g_losses)),
        }
        print(
            f"Epoch {epoch + 1}/{n_epochs}: "
            f"d_loss={epoch_record['d_loss']:.3f}, g_loss={epoch_record['g_loss']:.3f}"
        )

        if (epoch + 1) % eval_interval == 0:
            epoch_record.update(
                summarise_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=n_eval_samples)
            )
        history.append(epoch_record)

    return pd.DataFrame(history)

# %% [markdown]
# Create the discriminator, generator, and combined GAN. Review the summaries and check the input and output shapes before training.

# %%
latent_dim = 100

d_model = define_discriminator()
g_model = define_generator(latent_dim)

print("Discriminator")
d_model.summary()
print("Generator")
g_model.summary()

gan_model = define_gan(g_model, d_model)
print("GAN")
gan_model.summary()

# %% [markdown]
# <a id="5-practical-exercise-train-and-inspect-generated-images"></a>
#
# ### 5. Practical Exercise: Train and Inspect Generated Images
#
# Run the bounded training loop. With the default `quick` preset, the generated images are not expected to be high quality. They should still show how the training loop, generated samples, and diagnostics fit together.
#
# For a longer demonstration, switch to a GPU runtime and set `TRAINING_PRESET = "gpu_demo"` before rerunning the setup, data, model, and training cells.

# %%
training_history = train(
    generator_model=g_model,
    discriminator_model=d_model,
    gan_model=gan_model,
    dataset=working_dataset,
    latent_dim=latent_dim,
    n_epochs=training_config["n_epochs"],
    n_batch=training_config["n_batch"],
    eval_interval=training_config["eval_interval"],
    n_eval_samples=training_config["n_eval_samples"],
)

training_history

# %% [markdown]
# Generate a fresh grid of images from the current in-memory generator. If training was skipped or very short, compare these images with the real-image grid and describe what is still missing.

# %%
latent_points = generate_latent_points(latent_dim, 25, random_state=RANDOM_STATE + 99)
generated_images = g_model.predict(latent_points, verbose=0)
show_image_grid(generated_images, n=5, title="Generated images from the current generator")

if SAVE_ARTIFACTS:
    saved_models = sorted(ARTIFACT_DIR.glob("generator_epoch_*.keras"))
    print("Saved generator models:", saved_models)
else:
    saved_models = []
    print("SAVE_ARTIFACTS is False, so no model files were written.")

# %% [markdown]
# Optional artifact handling: if you intentionally set `SAVE_ARTIFACTS = True`, load the latest saved generator and sample from it. Keep generated models and plots as runtime artifacts unless the teaching team explicitly approves adding them to repository history.

# %%
if saved_models:
    restored_generator = load_model(saved_models[-1], compile=False)
    restored_latent_points = generate_latent_points(latent_dim, 25, random_state=RANDOM_STATE + 123)
    restored_images = restored_generator.predict(restored_latent_points, verbose=0)
    show_image_grid(restored_images, n=5, title=f"Images from {saved_models[-1].name}")
else:
    print("No saved generator model is available. Use the in-memory generator from the previous cell, or set SAVE_ARTIFACTS = True before training.")

# %% [markdown]
# Try one controlled change and record the result. Keep the change small so you can explain the effect.

# %%
# TODO: choose one controlled change and rerun the relevant cells.
# Examples:
# - set DATASET_NAME = "fashion_mnist";
# - set TRAINING_PRESET = "skip" and compare the untrained generator output;
# - use TRAINING_PRESET = "gpu_demo" in a GPU runtime;
# - change latent_dim and rebuild the models.

experiment_notes = {
    "change_made": "Describe the one change you tested.",
    "expected_effect": "Write what you expected to happen.",
    "observed_effect": "Summarise what changed in the generated images or losses.",
    "runtime_notes": "Record whether the run used CPU or GPU and how long it took.",
}

experiment_notes

# %% [markdown]
# <a id="6-student-tasks"></a>
#
# ### 6. Student Tasks
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Task</strong></th>
# <th><strong>What you need to do</strong></th>
# <th><strong>Why it matters</strong></th>
# <th><strong>Expected evidence</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Task 1</td>
# <td>Identify the input and output shapes of the generator and discriminator.</td>
# <td>GAN errors often come from shape mismatches.</td>
# <td>A short note naming the latent-vector shape, generated-image shape, and discriminator output shape.</td>
# </tr>
# <tr>
# <td align="left">Task 2</td>
# <td>Run the default training preset and inspect the generated image grid.</td>
# <td>Early GAN outputs should be interpreted as a training diagnostic, not as final data.</td>
# <td>The training-history table and a brief interpretation of the generated image grid.</td>
# </tr>
# <tr>
# <td align="left">Task 3</td>
# <td>Make one controlled change, such as changing the dataset or switching to the GPU demonstration preset.</td>
# <td>Controlled experiments help separate model design effects from random training variation.</td>
# <td>Completed `experiment_notes` with expected effect, observed effect, and runtime notes.</td>
# </tr>
# <tr>
# <td align="left">Task 4</td>
# <td>Explain why generated model files and plots should normally remain runtime artifacts.</td>
# <td>Deep-learning notebooks can create large, stale, or environment-specific files.</td>
# <td>A two- or three-sentence repository hygiene note.</td>
# </tr>
# </tbody>
# </table>
#
# </div>

# %% [markdown]
# <a id="7-reflection-and-references"></a>
#
# ### 7. Reflection and References
#
# Run the quick checks first, then answer the reflection questions.

# %%
assert working_dataset.ndim == 4
assert working_dataset.shape[1:] == (28, 28, 1)
assert working_dataset.min() >= 0.0 and working_dataset.max() <= 1.0
assert generated_images.shape == (25, 28, 28, 1)
assert np.isfinite(generated_images).all()

if not training_history.empty:
    assert {"epoch", "d_loss", "g_loss"}.issubset(training_history.columns)
    assert training_history["d_loss"].notna().all()
    assert training_history["g_loss"].notna().all()

print("Notebook checks passed.")

# %% [markdown]
# Reflection questions:
#
# 1. What does the discriminator learn that the generator can use indirectly?
# 2. Why can a short GAN run produce noisy images even when the code is correct?
# 3. What would you change first if you had access to a reliable GPU runtime?
# 4. What repository or reproducibility problems could occur if generated `.keras`, `.h5`, or `.png` files were added to repository history by accident?
#
# Further readings:
#
# - Goodfellow, I. et al. (2014). Generative Adversarial Networks. https://arxiv.org/abs/1406.2661
# - TensorFlow. Deep Convolutional Generative Adversarial Network. https://www.tensorflow.org/tutorials/generative/dcgan
# - Keras API documentation: built-in small datasets. https://keras.io/api/datasets/
# - Brownlee, J. How to Develop a GAN for Generating MNIST Handwritten Digits. https://machinelearningmastery.com/how-to-develop-a-generative-adversarial-network-for-mnist-handwritten-digits-from-scratch-in-keras/
