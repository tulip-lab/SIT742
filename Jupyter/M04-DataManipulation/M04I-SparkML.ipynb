# %% [markdown]
# ![Cloud-First](../image/CloudFirst.png)
#
# # SIT742: Modern Data Science
# **(Module 04: Data Manipulation)**
#
# **Session 4I: Spark ML Feature Engineering and Text Classification**
#
# ---
#
# - Materials in this module have been developed to support practical learning in modern data science, big data processing, and applied analytics.
# - Materials may include adapted or referenced open-source resources. Keep attribution and licence notes where applicable.
# - The public notebook collection is available in [SIT742](https://github.com/tulip-lab/sit742).
# - If you find any issue or bug in this document, please submit an issue at [SIT742](https://github.com/tulip-lab/sit742/issues).
# - Audience: Honours and Master's students using the Deakin SIT742 practical and self-learning materials.
#
# Prepared by the SIT742 Teaching Team.
#
# Maintained through the [TULIP Lab](https://www.tulip.academy) FLIP workflow.
#
# ---
#
# <div align="center">
#
# <table>
# <thead>
# <tr>
# <th><strong>Item</strong></th>
# <th><strong>Description</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td align="left">Module context</td>
# <td>This notebook is one component of the practical and self-learning materials for Module 04.</td>
# </tr>
# <tr>
# <td align="left">Estimated duration</td>
# <td>Approximately 40 minutes, based on 240 minutes of M04 practical/self-learning work divided across six M04 notebooks.</td>
# </tr>
# <tr>
# <td align="left">Main packages</td>
# <td><code>pyspark</code>, especially <code>pyspark.ml</code>. Spark also requires a Java runtime.</td>
# </tr>
# <tr>
# <td align="left">Data files</td>
# <td>No external data files. The examples use small in-memory sample DataFrames.</td>
# </tr>
# </tbody>
# </table>
#
# </div>
#
# ---
#
# **Table of Contents**
#
# - [1. Overview and Learning Goals](#1-overview-and-learning-goals)
# - [2. Setup and Spark Session](#2-setup-and-spark-session)
# - [3. Text Feature Transformers](#3-text-feature-transformers)
# - [4. Advanced Feature Engineering](#4-advanced-feature-engineering)
# - [5. Imputation and Binning](#5-imputation-and-binning)
# - [6. Text Classification Pipeline](#6-text-classification-pipeline)
# - [7. Practical Checks](#7-practical-checks)
# - [8. Reflection and References](#8-reflection-and-references)

# %% [markdown]
# <a id="1-overview-and-learning-goals"></a>
#
# ### 1. Overview and Learning Goals
#
# This session introduces common Spark ML feature engineering tools. The examples use small in-memory DataFrames so that you can focus on transformer behaviour, vector outputs, and pipeline composition without needing an external dataset.
#
# By the end of this practical, you should be able to:
#
# 1. start a Spark session for `pyspark.ml` work;
# 2. use text feature transformers such as `Word2Vec`, `Tokenizer`, `RegexTokenizer`, `StopWordsRemover`, `NGram`, and `CountVectorizer`;
# 3. use numeric feature transformers such as `Binarizer`, `PCA`, `PolynomialExpansion`, and `MinMaxScaler`;
# 4. apply bucketing and imputation to simple feature columns;
# 5. assemble a small text classification pipeline with Spark ML stages;
# 6. interpret the limits of very small demonstration datasets.

# %% [markdown]
# <a id="2-setup-and-spark-session"></a>
#
# ### 2. Setup and Spark Session
#
# This notebook has no external data files. It still requires Java and PySpark because all examples run through Spark.
#
# #### Option A: Google Colab / online execution
#
# Use this option when you are running the notebook in Google Colab or another online notebook environment. The setup code installs PySpark if required and checks for a Java runtime.
#
# #### Option B: Local execution
#
# Use this option when Java and PySpark are already installed in your active Python environment. No repository clone is required for data loading in this notebook because all sample data is created in code.
#
# Keep `EXECUTION_MODE = "online"` for Option A. Change it to `"local"` only for Option B.

# %%
import importlib.util
import shutil
import subprocess
import sys

EXECUTION_MODE = "online"  # Use "online" for Google Colab; use "local" for an environment with Java and PySpark installed.
PYSPARK_PACKAGE = "pyspark==3.5.1"


def ensure_java_available():
    if shutil.which("java"):
        return
    if shutil.which("apt-get"):
        subprocess.run(["apt-get", "update"], check=True)
        subprocess.run(["apt-get", "install", "-y", "openjdk-17-jdk-headless"], check=True)
        return
    raise RuntimeError(
        "Java is required for Spark. Use Google Colab, or install a supported Java runtime locally."
    )


def ensure_python_module(module_name, package_name):
    if importlib.util.find_spec(module_name) is not None:
        return
    if EXECUTION_MODE == "online":
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", package_name])
        return
    raise RuntimeError(
        f"{package_name} is required. Install it in the active environment with: python -m pip install {package_name}"
    )


ensure_java_available()
ensure_python_module("pyspark", PYSPARK_PACKAGE)

print("Execution mode:", EXECUTION_MODE)

# %% [markdown]
# #### 2.1 Start Spark

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("SIT742-M04I-SparkML")
    .config("spark.ui.showConsoleProgress", "false")
    .getOrCreate()
)
spark.sparkContext.setLogLevel("WARN")

print("Spark version:", spark.version)
print("Spark master:", spark.sparkContext.master)

# %% [markdown]
# <a id="3-text-feature-transformers"></a>
#
# ### 3. Text Feature Transformers
#
# Spark ML transformers convert one or more input columns into output columns. Text transformers usually convert raw strings or token arrays into token lists, n-grams, counts, or learned vector representations.
#
# #### 3.1 Word2Vec in Spark

# %%
from pyspark.ml.feature import Word2Vec

# Input data: each row is a bag of words from a sentence or short document.
documentDF = spark.createDataFrame([
    ("Hi this is from SIT742".split(" "),),
    ("I think SIT742 is a good unit".split(" "),),
    ("Spark is not hard to learn".split(" "),),
], ["text"])

word2Vec = Word2Vec(vectorSize=3, minCount=0, inputCol="text", outputCol="result")
model = word2Vec.fit(documentDF)

result = model.transform(documentDF)
for row in result.collect():
    print(f"Text: {row['text']} => Vector: {row['result']}")

# %% [markdown]
# #### 3.2 Tokenization and regex tokenization

# %%
from pyspark.ml.feature import Tokenizer, RegexTokenizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

sentenceDataFrame = spark.createDataFrame([
    (0, "Hi|this|is|from|SIT742"),
    (1, "I     think SIT742  is a  good unit"),
    (2, "Spark,is,not,hard,to,learn"),
], ["id", "sentence"])

tokenizer = Tokenizer(inputCol="sentence", outputCol="words")
regexTokenizer = RegexTokenizer(inputCol="sentence", outputCol="regex_words", pattern=r"\W")
countTokens = udf(lambda words: len(words), IntegerType())

tokenized = tokenizer.transform(sentenceDataFrame)
tokenized.select("sentence", "words").withColumn("tokens", countTokens(col("words"))).show(truncate=False)

regexTokenized = regexTokenizer.transform(sentenceDataFrame)
regexTokenized.select("sentence", "regex_words").withColumn("tokens", countTokens(col("regex_words"))).show(truncate=False)

# %% [markdown]
# #### 3.3 Stop words removal

# %%
from pyspark.ml.feature import StopWordsRemover

sentenceData = spark.createDataFrame([
    (0, ["I", "LIKE", "the", "UNIT", "?"]),
    (1, ["THANKS", "AGAIN", "for", "your", "help"]),
], ["id", "raw"])

remover = StopWordsRemover(inputCol="raw", outputCol="filtered")
remover.transform(sentenceData).show(truncate=False)

# %% [markdown]
# #### 3.4 N-gram tokenization

# %%
from pyspark.ml.feature import NGram, Tokenizer

sentenceDataFrame = spark.createDataFrame([
    (0, "Hi this is from SIT742"),
    (1, "I think SIT742 is a good unit"),
    (2, "Spark is not hard to learn"),
], ["id", "sentence"])

tokenizer = Tokenizer(inputCol="sentence", outputCol="words")
wordDataFrame = tokenizer.transform(sentenceDataFrame)

ngram = NGram(n=2, inputCol="words", outputCol="ngrams")
ngramDataFrame = ngram.transform(wordDataFrame)
ngramDataFrame.select("sentence", "ngrams").show(truncate=False)

# %% [markdown]
# #### 3.5 CountVectorizer representation

# %%
from pyspark.ml.feature import CountVectorizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import ArrayType, StringType

word_df = spark.createDataFrame([
    (0, "Hi this is from SIT742".split(" ")),
    (1, "I think SIT742 is a good unit".split(" ")),
], ["id", "words"])

lowercase_udf = udf(lambda words: [word.lower() for word in words], ArrayType(StringType()))
word_df_lower = word_df.withColumn("words_lower", lowercase_udf(col("words")))

cv = CountVectorizer(inputCol="words_lower", outputCol="features", minDF=1.0)
cv_model = cv.fit(word_df_lower)
cv_result = cv_model.transform(word_df_lower)

cv_result.select("id", "words_lower", "features").show(truncate=False)
print("Vocabulary learned by CountVectorizer:")
print(cv_model.vocabulary)

# %% [markdown]
# <a id="4-advanced-feature-engineering"></a>
#
# ### 4. Advanced Feature Engineering
#
# The next examples show numeric feature transformations. The data is intentionally small so that the output structure is easy to inspect.
#
# #### 4.1 Binarizer on a continuous feature

# %%
from pyspark.ml.feature import Binarizer

continuousDataFrame = spark.createDataFrame([
    (0, 3.1),
    (1, 9.3),
    (2, 27.9),
], ["id", "feature"])

binarizer = Binarizer(threshold=9.3, inputCol="feature", outputCol="binarized_feature")
binarizedDataFrame = binarizer.transform(continuousDataFrame)

print("Binarizer output with threshold =", binarizer.getThreshold())
binarizedDataFrame.show()

# %% [markdown]
# #### 4.2 PCA in Spark

# %%
from pyspark.ml.feature import PCA
from pyspark.ml.linalg import Vectors

pca_data = [
    (Vectors.sparse(5, [(1, 3.5), (2, 9.5)]),),
    (Vectors.dense([1.0, 2.0, 4.0, 5.0, 6.0]),),
    (Vectors.dense([2.0, 3.0, 5.0, 7.0, 9.0]),),
]
pca_df = spark.createDataFrame(pca_data, ["features"])

pca = PCA(k=3, inputCol="features", outputCol="pcaFeatures")
pca_model = pca.fit(pca_df)
pca_result = pca_model.transform(pca_df).select("pcaFeatures")
pca_result.show(truncate=False)

# %% [markdown]
# #### 4.3 Polynomial representation for continuous data

# %%
from pyspark.ml.feature import PolynomialExpansion
from pyspark.ml.linalg import Vectors

poly_input_df = spark.createDataFrame([
    (Vectors.dense([3.0, 3.0]),),
    (Vectors.dense([9.0, 3.0]),),
], ["features"])

polyExpansion = PolynomialExpansion(degree=5, inputCol="features", outputCol="polyFeatures")
poly_df = polyExpansion.transform(poly_input_df)
poly_df.show(truncate=False)

# %% [markdown]
# #### 4.4 Min-max scaling

# %%
from pyspark.ml.feature import MinMaxScaler
from pyspark.ml.linalg import Vectors

scaler_input_df = spark.createDataFrame([
    (0, Vectors.dense([1.0, 2.1, -18.0, 100.0]),),
    (1, Vectors.dense([2.0, 2.0, -22.0, 200.0]),),
    (2, Vectors.dense([4.0, 1000.0, 18.0, 0.0]),),
], ["id", "features"])

scaler = MinMaxScaler(inputCol="features", outputCol="scaledFeatures")
scalerModel = scaler.fit(scaler_input_df)
scaledData = scalerModel.transform(scaler_input_df)
scaledData.select("features", "scaledFeatures").show(truncate=False)

# %% [markdown]
# <a id="5-imputation-and-binning"></a>
#
# ### 5. Imputation and Binning
#
# Spark ML also includes tools for turning continuous values into buckets and filling missing numeric values.
#
# #### 5.1 Discretization with Bucketizer

# %%
from pyspark.ml.feature import Bucketizer

splits = [-float("inf"), -0.5, 0.0, 0.5, float("inf")]
bucket_data = [(-221.9,), (-0.5,), (-0.1,), (0.1,), (3.2,), (1999.9,)]
bucket_df = spark.createDataFrame(bucket_data, ["features"])

bucketizer = Bucketizer(splits=splits, inputCol="features", outputCol="bucketedFeatures")
bucketedData = bucketizer.transform(bucket_df)

print("Bucketizer output with", len(bucketizer.getSplits()) - 1, "buckets")
bucketedData.show()

# %% [markdown]
# #### 5.2 Imputation in Spark

# %%
from pyspark.ml.feature import Imputer

imputer_df = spark.createDataFrame([
    (2.0, float("nan")),
    (3.0, float("nan")),
    (float("nan"), 7.0),
    (4.0, 4.0),
    (5.0, 7.0),
], ["a", "b"])

imputer = Imputer(inputCols=["a", "b"], outputCols=["out_a", "out_b"])
imputer_model = imputer.fit(imputer_df)
imputer_model.transform(imputer_df).show()

# %% [markdown]
# <a id="6-text-classification-pipeline"></a>
#
# ### 6. Text Classification Pipeline
#
# A Spark ML pipeline chains transformers and estimators. This small example is only a demonstration of pipeline mechanics; the dataset is too small to support a meaningful model evaluation.

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.sql import functions as F

text_data = [
    (0, "I find this unit challenging", 0),
    (1, "This is an engaging practical", 1),
    (2, "The material is difficult today", 0),
    (3, "What a useful data science subject", 1),
    (4, "This unit is not easy", 0),
    (5, "Excellent examples and teaching", 1),
]
text_df = spark.createDataFrame(text_data, ["id", "text", "label"])

pipeline_tokenizer = Tokenizer(inputCol="text", outputCol="words")
pipeline_remover = StopWordsRemover(inputCol="words", outputCol="filtered_words")
pipeline_vectorizer = CountVectorizer(inputCol="filtered_words", outputCol="raw_features")
pipeline_idf = IDF(inputCol="raw_features", outputCol="features")
pipeline_lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10)

pipeline = Pipeline(stages=[pipeline_tokenizer, pipeline_remover, pipeline_vectorizer, pipeline_idf, pipeline_lr])

train_data = text_df.filter(F.col("id") < 4)
test_data = text_df.filter(F.col("id") >= 4)

pipeline_model = pipeline.fit(train_data)
predictions = pipeline_model.transform(test_data)
predictions.select("text", "label", "prediction", "probability").show(truncate=False)

evaluator = BinaryClassificationEvaluator(labelCol="label")
auc = evaluator.evaluate(predictions)
print(f"Test AUC on the tiny demonstration split = {auc:.3f}")

# %% [markdown]
# <a id="7-practical-checks"></a>
#
# ### 7. Practical Checks
#
# Use these checks to confirm that the main objects were created. They check notebook state, not model quality.

# %%
assert documentDF.count() == 3
assert len(cv_model.vocabulary) >= 5
assert scaledData.count() == 3
assert bucketedData.count() == 6
assert imputer_model.transform(imputer_df).count() == 5
assert predictions.count() == 2

print("Spark ML practical checks passed.")

# %% [markdown]
# <a id="8-reflection-and-references"></a>
#
# ### 8. Reflection and References
#
# Reflect on the following questions:
#
# 1. Which text transformer changes a string column into a token array?
# 2. Why does `CountVectorizer` need to be fitted before it can transform data?
# 3. What does `IDF` add after raw term counts have been created?
# 4. Why should the final classifier example be treated as a pipeline demonstration rather than evidence of model performance?
# 5. Which feature transformer from this notebook would be useful for your own text or tabular data workflow?
#
# References:
#
# - Apache Spark documentation: [Spark MLlib Guide](https://spark.apache.org/docs/latest/ml-guide.html)
# - Apache Spark documentation: [Feature Extractors and Transformers](https://spark.apache.org/docs/latest/ml-features.html)
# - Apache Spark documentation: [ML Pipelines](https://spark.apache.org/docs/latest/ml-pipeline.html)
